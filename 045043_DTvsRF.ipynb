# %% [markdown]
# #**Airline Satisfaction through Supervised Learning (Decision Tree VS Random Forest)**
#
# **1. Project Objectives | Problem Statements**
#
# 1.1. PO1 | PS1: Segmentation of Airline Data using Supervised Machine Learning Algorithms
#
# 1.2. PO2 | PS2: Implement the random forest algorithm to enhance prediction accuracy compared to the decision tree. Assess random forest performance in terms of accuracy and computational resources.
# Apply XGBoost algorithm to further improve prediction accuracy as an ensemble learning technique. Compare XGBoost performance with decision tree and random forest models.
#
#
# 1.3. PO3 | PS3: Evaluate decision tree, random forest, and XGBoost models based on metrics like accuracy, precision, recall, F1-score, execution time, and memory usage to determine the most suitable model for customer segmentation and prediction.
#
# **2. Description of Data**
#
# #### 2.1. Data Source, Shape
#
# 2.1.1. Data Source (https://www.kaggle.com/datasets/teejmahal20/airline-passenger-satisfaction)
#
# 2.1.3. Data Shape (Dimension: Number of Variables-25 | Number of Records-103904 rows × 25 columns)
#
#
# **2.2. Description of Variables**
#
# **2.2.1. Index Variable(s)**
#
# Index Variable(s): ID
#
# **.2.2. Variables or Features having Categories | Categorical Variables or Features (CV)**
#
# **2.2.2.1. Variables or Features having Nominal Categories | Categorical
# Variables or Features - Nominal Type**
#
# **Nominal Categories:**
#
# Gender
#
# Customer Type
#
# Type of Travel
#
# Class
#
# **2.2.2.2. Variables or Features having Ordinal Categories | Categorical Variables or Features - Ordinal Type**
#
# **Ordinal Categories:**
#
# Satisfaction
#
# Inflight wifi service
#
# Departure/Arrival time convenient
#
# Ease of Online booking
#
# Gate location
#
# Food and drink
#
# Online boarding
#
# Seat comfort
#
# Inflight entertainment
#
# On-board service
#
# Leg room service
#
# Baggage handling
#
# Check-in service
#
# Inflight service
#
# Cleanliness
#
# **2.2.3. Non-Categorical Variables or Features
# Non-Categorical Variables or Features:**
#
#
# Age
#
# Flight distance
#
# Departure Delay in Minutes
#
# Arrival Delay in Minutes
#
# **Variable Description:**
#
# **Index Variable:**
#
# ID
#
# **Categorical Variables:**
#
# **Nominal Categories:**
#
# Gender - Gender of the passengers (Female, Male)
#
# Customer Type - The customer type (Loyal customer, disloyal customer)
#
#
# Type of Travel - Purpose of the flight of the passengers (Personal Travel, Business Travel)
#
# Class - Travel class in the plane of the passengers (Business, Eco, Eco Plus)
#
#
# Inflight wifi service - Satisfaction level of the inflight wifi service (0:Not Applicable;1-5)
#
# Departure/Arrival time convenient - Satisfaction level of Departure/Arrival time convenient
#
# Ease of Online booking - Satisfaction level of online booking
#
# Gate location - Satisfaction level of Gate location
#
# Food and drink - Satisfaction level of Food and drink
#
# Online boarding - Satisfaction level of online boarding
#
# Seat comfort - Satisfaction level of Seat comfort
#
# Inflight entertainment - Satisfaction level of inflight entertainment
#
# On-board service - Satisfaction level of On-board service
#
# Leg room service - Satisfaction level of Leg room service
#
# Baggage handling - Satisfaction level of baggage handling
#
# Check-in service - Satisfaction level of Check-in service
#
# Inflight service - Satisfaction level of inflight service
#
# Cleanliness - Satisfaction level of Cleanliness
#
# Satisfaction - Airline satisfaction level(Satisfaction, neutral or dissatisfaction)
#
# **Non-Categorical Variables:**
#
#
# Age - The actual age of the passengers
#
# Flight distance - The flight distance of this journey
#
# Departure Delay in Minutes - Minutes delayed when departure
#
# Arrival Delay in Minutes - Minutes delayed when Arrival
#
#
#
# #### **2.3 Descriptive Statistics: Non-Categorical Variables or Features**
# ##### **2.3.1.1. Measures of Central Tendency**
# - **Mean:**
#    - Age: 39.380466
#
#    - Flight distance: 1189.325202
#
#    - Departure Delay in Minutes: 14.747939
#
#    - Arrival Delay in Minutes: 15.178678
#
# ##### **2.3.2.2. Measures of Dispersion**
# - **Standard Deviation:**
#    - Age: 15.113125
#
#    - Flight distance: 997.297235
#
#    - Departure Delay in Minutes: 38.116737
#
#    - Arrival Delay in Minutes: 38.698682
#
#
# ### **3.1. Data Pre-Processing**
#
# #### **3.1.1. Missing Data Statistics and Treatment**
# - **Variable-wise Missing Data Information:**
#    - Arrival Delay in Minutes  -           310 values missing
#
# - **Record-wise Missing Data Information (Top 5 Records):**
#    - No records with missing data.
#
# #### 3.1.2. Numerical Encoding of Categorical Variables or Features
# - **Ordinal Encoder:**
#    - Used to encode categorical variables into numerical format.
#
# #### 3.1.3. Outlier Statistics and Treatment
# - **Outlier Detection:**
#    - Identified outliers using boxplot visualization.
#
# - **Outlier Treatment:**
#    - Outliers treated by performing normalization using Min-Max Scaler.
#
# #### 3.1.4. Data Transformation and Scaling
# - **Normalization:**
#    - Min-Max Scaling applied to non-categorical variables to bring them within a common scale.
#
# #### 3.1.5. Pre-Processed Dataset
# - **Pre-Processed Categorical Data Subset:**
#    - Encoded categorical data using Ordinal Encoder.
#
# - **Pre-Processed Non-Categorical Data Subset:**
#    - Normalized non-categorical data using Min-Max Scaler.
#
# - **Pre-Processed Dataset:**
#    - Merged pre-processed categorical and non-categorical data subsets.
#
# ### **4. Findings** (**Supervised Learning**)
#
# **Decision Tree Report Summary**
#
# Precision, Recall, and F1-score: The decision tree model performs well in predicting class 0, with a precision, recall, and F1-score of 0.85, 1.00, and 0.92 respectively. However, it performs poorly for classes 1, 2, and 3, with all metrics at 0.00. This indicates that the model struggles to correctly classify these classes.
#
# Accuracy: The overall accuracy of the decision tree model is 0.85, meaning it correctly predicts the telecom customer segments 85% of the time.
#
# Macro and Weighted Average Metrics: The macro average precision, recall, and F1-score are 0.21, 0.25, and 0.23 respectively, while the weighted average precision, recall, and F1-score are 0.72, 0.85, and 0.78 respectively. These metrics provide a summarized view of the model's performance across all classes, considering class imbalances.
#
# Execution Time and Memory Usage: The decision tree model takes a negligible time of approximately 0.00004124 seconds for execution and utilizes 616.82 MB of memory, indicating minimal computational requirements.
#
#
# **Random Forest Report Summary**
#
# Precision, Recall, and F1-score: The precision, recall, and F1-score vary across different classes, with class 0 having the highest values (0.85, 0.99, and 0.91 respectively). However, the precision, recall, and F1-score for classes 1, 2, and 3 are considerably lower, indicating poor performance in correctly identifying these classes.
#
# Accuracy: The overall accuracy of the Random Forest model is 0.84, meaning it correctly predicts the telecom customer segments 84% of the time.
#
# Macro and Weighted Average Metrics: The macro average precision, recall, and F1-score are 0.24, 0.25, and 0.23 respectively, while the weighted average precision, recall, and F1-score are 0.74, 0.84, and 0.78 respectively. These metrics provide a summarized view of the model's performance across all classes, considering class imbalances.
#
# Execution Time and Memory Usage: The Random Forest model takes approximately 11.39 seconds for execution and utilizes 1520.32 MB of memory, indicating moderate computational requirements.
#
#
# **XGBoost Report Summary:**
#
# Precision, Recall, and F1-score: The precision, recall, and F1-score for XGBoost are similar to those of Random Forest, with class 3 having the highest values (0.47, 1.00, and 0.64 respectively). However, the precision, recall, and F1-score for classes 0, 1, 2, and 4 are relatively low, indicating poor performance in correctly identifying these classes.
#
# Accuracy: The overall accuracy of the XGBoost model is 0.47, which is consistent with Random Forest and indicates suboptimal performance in predicting telecom customer segments.
#
# Macro and Weighted Average Metrics: The macro average precision, recall, and F1-score are 0.15, 0.20, and 0.13 respectively, while the weighted average precision, recall, and F1-score are 0.27, 0.47, and 0.30 respectively. These metrics provide a summarized view of the model's performance across all classes, taking into account class imbalances.
#
# Execution Time and Memory Usage: XGBoost demonstrates relatively low execution time (31.71 seconds) and memory usage (1557.88 MB) compared to Random Forest, suggesting it is more computationally efficient.
#
# **Random Forest VS Decision Tree(Base Model)**
#
# Precision, Recall, and F1-score:
#
# Decision Tree: The Decision Tree model performs well in predicting class 0 with high precision, recall, and F1-score. However, it performs poorly for classes 1, 2, and 3, with all metrics at 0.00, indicating an inability to correctly classify these classes.
#
# Random Forest: The Random Forest model shows varying performance across different classes. While class 0 has high precision, recall, and F1-score, classes 1, 2, and 3 exhibit considerably lower values, suggesting difficulty in identifying these classes accurately.
#
# Accuracy:
#
# Decision Tree: The overall accuracy of the Decision Tree model is 0.85, indicating that it correctly predicts the telecom customer segments 85% of the time.
#
# Random Forest: The overall accuracy of the Random Forest model is slightly lower at 0.84, meaning it correctly predicts the segments 84% of the time.
#
# Macro and Weighted Average Metrics:
#
# Decision Tree: For both macro and weighted average metrics, the Decision Tree model shows relatively consistent precision, recall, and F1-score values, indicating a balanced performance across all classes.
#
# Random Forest: While the macro average precision, recall, and F1-score are lower compared to the Decision Tree, the weighted average precision, recall, and F1-score are slightly higher, suggesting that the Random Forest model is better at handling class imbalances.
#
# Execution Time and Memory Usage:
#
# Decision Tree: The Decision Tree model exhibits minimal computational requirements, with a negligible execution time of approximately 0.00004124 seconds and memory usage of 616.82 MB.
#
# Random Forest: In contrast, the Random Forest model requires moderate computational resources, with an execution time of approximately 11.39 seconds and memory usage of 1520.32 MB.
#
# **XGBoost VS Decision Tree(Base Model):**
#
# Precision, Recall, and F1-score:
#
# Decision Tree: The Decision Tree model performs well in predicting class 0, with high precision, recall, and F1-score. However, it struggles with classes 1, 2, and 3, where all metrics are at 0.00, indicating an inability to correctly classify these classes.
#
# XGBoost: XGBoost shows similar performance to Random Forest, with class 3 having the highest precision, recall, and F1-score. However, classes 0, 1, 2, and 4 exhibit relatively low values, indicating poor performance in correctly identifying these classes.
#
# Accuracy:
#
# Decision Tree: The overall accuracy of the Decision Tree model is 0.85, indicating it correctly predicts telecom customer segments 85% of the time.
#
# XGBoost: The overall accuracy of the XGBoost model is lower at 0.47, consistent with Random Forest, suggesting suboptimal performance in predicting telecom customer segments.
#
# Macro and Weighted Average Metrics:
#
# Decision Tree: For both macro and weighted average metrics, the Decision Tree model shows consistent precision, recall, and F1-score values, providing a balanced performance across all classes.
#
# XGBoost: XGBoost demonstrates lower macro average precision, recall, and F1-score compared to Decision Tree. However, the weighted average precision, recall, and F1-score are similar, indicating a summarized view of performance considering class imbalances.
#
# Execution Time and Memory Usage:
#
# Decision Tree: The Decision Tree model requires minimal computational resources, with a negligible execution time of approximately 0.00004124 seconds and memory usage of 616.82 MB.
#
# XGBoost: XGBoost demonstrates relatively low execution time (31.71 seconds) and memory usage (1557.88 MB) compared to Random Forest, suggesting it is more computationally efficient.
#
# In summary, both models have their strengths and weaknesses. The Decision Tree model shows better performance for class 0 but struggles with other classes. XGBoost performs similarly to Random Forest, indicating potential for improvement in correctly identifying certain classes. The choice between the two models depends on the specific requirements and priorities of the application, with XGBoost offering better computational efficiency but lower accuracy compared to the Decision Tree.
#
# ###**5. Managerial Implications**
#
# Model Selection:
#
# Decision Tree vs. Random Forest vs. XGBoost:
#
# Decision Tree offers a good balance between accuracy and computational efficiency. It's suitable when interpretability is crucial and computational resources are limited.
# Random Forest and XGBoost, while providing potentially higher accuracy, come with increased computational requirements. They are suitable when higher accuracy is paramount and computational resources are sufficient.
#
# Customer Segmentation:
#
# Segmentation Insights:
# Utilize the segmentation provided by the models to understand distinct customer groups.
# Decision Tree segmentation can offer insights into easily interpretable patterns, aiding in targeted marketing strategies.
# Random Forest and XGBoost can provide more nuanced segmentation, potentially uncovering hidden patterns or trends among customer groups.
# Marketing and Service Improvement:
#
# Resource Allocation:
#
# Allocate resources efficiently based on the computational requirements of each model.
# Decision Tree may be preferred in scenarios where computational resources are constrained, while Random Forest or XGBoost can be utilized when higher accuracy warrants the additional computational overhead.
#
# Real-time Decision Making:
#
# Consider the real-time execution capabilities of each model when deploying them for operational decision-making.
# Decision Tree's minimal computational requirements make it suitable for real-time applications where quick decisions are crucial.
#
# Continuous Monitoring and Iteration:
#
# Model Evaluation:
#
# Continuously monitor the performance of the deployed models and iterate as necessary.
# Regularly reassess the segmentation and satisfaction scores provided by the models to ensure they remain relevant and accurate.
# Feedback Incorporation:
#
# Incorporate feedback from customer interactions and market dynamics to refine and improve the models over time.
# Adapt segmentation strategies and service enhancements based on evolving customer preferences and industry trends.

# %%
# Required Libraries
import pandas as pd, numpy as np # For Data Manipulation
import matplotlib.pyplot as plt, seaborn as sns # For Data Visualization
from sklearn.model_selection import train_test_split # For Splitting Data into Training & Testing Sets
from sklearn.tree import DecisionTreeClassifier, export_text, plot_tree  # For Decision Tree Model
from sklearn.metrics import confusion_matrix, classification_report # For Decision Tree Model Evaluation
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder # For Encoding Categorical Data [Nominal | Ordinal]
from sklearn.preprocessing import OneHotEncoder # For Creating Dummy Variables of Categorical Data [Nominal]
from sklearn.impute import SimpleImputer, KNNImputer # For Imputation of Missing Data
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler # For Rescaling Data
from sklearn.model_selection import train_test_split # For Splitting Data into Training & Testing Sets
import pandas as pd, numpy as np # For Data Manipulation
import matplotlib.pyplot as plt, seaborn as sns # For Data Visualization
import seaborn as sns
import os
import scipy.cluster.hierarchy as sch # For Hierarchical Clustering
from sklearn.cluster import AgglomerativeClustering as agclus, KMeans as kmclus # For Agglomerative & K-Means Clustering
from sklearn.metrics import silhouette_score as sscore, davies_bouldin_score as dbscore # For Clustering Model Evaluation
import math
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler # For Rescaling Data
#from sklearn.model_selection import train_test_split # For Splitting Data into Training & Testing Sets
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import Pipeline
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, StratifiedShuffleSplit
from sklearn.tree import DecisionTreeClassifier, export_text, plot_tree  # For Decision Tree Model
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.metrics import confusion_matrix, classification_report # For Decision Tree Model Evaluation
from sklearn.neighbors import KNeighborsClassifier
from sklearn.decomposition import PCA
from matplotlib.colors import ListedColormap
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix, accuracy_score
from matplotlib.colors import ListedColormap

# %%
df=pd.read_csv("airline_satisfaction.csv")
df
# Out:
#         Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 0                0   70172    Male     Loyal Customer   13  Personal Travel
# 1                1    5047    Male  disloyal Customer   25  Business travel
# 2                2  110028  Female     Loyal Customer   26  Business travel
# 3                3   24026  Female     Loyal Customer   25  Business travel
# 4                4  119299    Male     Loyal Customer   61  Business travel
# ...            ...     ...     ...                ...  ...              ...
# 103899      103899   94171  Female  disloyal Customer   23  Business travel
# 103900      103900   73097    Male     Loyal Customer   49  Business travel
# 103901      103901   68825    Male  disloyal Customer   30  Business travel
# 103902      103902   54173  Female  disloyal Customer   22  Business travel
# 103903      103903   62567    Male     Loyal Customer   27  Business travel
#
#            Class  Flight Distance  Inflight wifi service  \
# 0       Eco Plus              460                      3
# 1       Business              235                      3
# 2       Business             1142                      2
# 3       Business              562                      2
# 4       Business              214                      3
# ...          ...              ...                    ...
# 103899       Eco              192                      2
# 103900  Business             2347                      4
# 103901  Business             1995                      1
# 103902       Eco             1000                      1
# 103903  Business             1723                      1
#
#         Departure/Arrival time convenient  ...  Inflight entertainment  \
# 0                                       4  ...                       5
# 1                                       2  ...                       1
# 2                                       2  ...                       5
# 3                                       5  ...                       2
# 4                                       3  ...                       3
# ...                                   ...  ...                     ...
# 103899                                  1  ...                       2
# 103900                                  4  ...                       5
# 103901                                  1  ...                       4
# 103902                                  1  ...                       1
# 103903                                  3  ...                       1
#
#         On-board service  Leg room service  Baggage handling  Checkin service  \
# 0                      4                 3                 4                4
# 1                      1                 5                 3                1
# 2                      4                 3                 4                4
# 3                      2                 5                 3                1
# 4                      3                 4                 4                3
# ...                  ...               ...               ...              ...
# 103899                 3                 1                 4                2
# 103900                 5                 5                 5                5
# 103901                 3                 2                 4                5
# 103902                 4                 5                 1                5
# 103903                 1                 1                 4                4
#
#         Inflight service  Cleanliness  Departure Delay in Minutes  \
# 0                      5            5                          25
# 1                      4            1                           1
# 2                      4            5                           0
# 3                      4            2                          11
# 4                      3            3                           0
# ...                  ...          ...                         ...
# 103899                 3            2                           3
# 103900                 5            4                           0
# 103901                 5            4                           7
# 103902                 4            1                           0
# 103903                 3            1                           0
#
#         Arrival Delay in Minutes             satisfaction
# 0                           18.0  neutral or dissatisfied
# 1                            6.0  neutral or dissatisfied
# 2                            0.0                satisfied
# 3                            9.0  neutral or dissatisfied
# 4                            0.0                satisfied
# ...                          ...                      ...
# 103899                       0.0  neutral or dissatisfied
# 103900                       0.0                satisfied
# 103901                      14.0  neutral or dissatisfied
# 103902                       0.0  neutral or dissatisfied
# 103903                       0.0  neutral or dissatisfied
#
# [103904 rows x 25 columns]

# %%
df_cat = df[['Gender', 'Customer Type', 'Type of Travel', 'Class', 'satisfaction',
                         'Inflight wifi service', 'Departure/Arrival time convenient', 'Ease of Online booking',
                         'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
                         'Inflight entertainment', 'On-board service', 'Leg room service',
                         'Baggage handling', 'Checkin service', 'Inflight service', 'Cleanliness']] # Categorical Data [Nominal | Ordinal]
df_noncat = df[['Age', 'Flight Distance', 'Departure Delay in Minutes', 'Arrival Delay in Minutes']] # Non-Categorical Data

# %%
print(df.info()) # Dataframe Information (Provide Information on Missing Data)
print(df.describe())
variable_missing_data = df.isna().sum(); variable_missing_data # Variable-wise Missing Data Information
print(variable_missing_data)
record_missing_data = df.isna().sum(axis=1).sort_values(ascending=False).head(5); record_missing_data # Record-wise Missing Data Information (Top 5)
print(record_missing_data)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103904 entries, 0 to 103903
# Data columns (total 25 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Unnamed: 0                         103904 non-null  int64
#  1   id                                 103904 non-null  int64
#  2   Gender                             103904 non-null  object
#  3   Customer Type                      103904 non-null  object
#  4   Age                                103904 non-null  int64
#  5   Type of Travel                     103904 non-null  object
#  6   Class                              103904 non-null  object
#  7   Flight Distance                    103904 non-null  int64
#  8   Inflight wifi service              103904 non-null  int64
#  9   Departure/Arrival time convenient  103904 non-null  int64
#  10  Ease of Online booking             103904 non-null  int64
#  11  Gate location                      103904 non-null  int64
#  12  Food and drink                     103904 non-null  int64
#  13  Online boarding                    103904 non-null  int64
#  14  Seat comfort                       103904 non-null  int64
#  15  Inflight entertainment             103904 non-null  int64
#  16  On-board service                   103904 non-null  int64
#  17  Leg room service                   103904 non-null  int64
#  18  Baggage handling                   103904 non-null  int64
#  19  Checkin service                    103904 non-null  int64
#  20  Inflight service                   103904 non-null  int64
#  21  Cleanliness                        103904 non-null  int64
#  22  Departure Delay in Minutes         103904 non-null  int64
#  23  Arrival Delay in Minutes           103594 non-null  float64
#  24  satisfaction                       103904 non-null  object
# dtypes: float64(1), int64(19), object(5)
# memory usage: 19.8+ MB
# None
#           Unnamed: 0             id            Age  Flight Distance  \
# count  103904.000000  103904.000000  103904.000000    103904.000000
# mean    51951.500000   64924.210502      39.379706      1189.448375
# std     29994.645522   37463.812252      15.114964       997.147281
# min         0.000000       1.000000       7.000000        31.000000
# 25%     25975.750000   32533.750000      27.000000       414.000000
# 50%     51951.500000   64856.500000      40.000000       843.000000
# 75%     77927.250000   97368.250000      51.000000      1743.000000
# max    103903.000000  129880.000000      85.000000      4983.000000
#
#        Inflight wifi service  Departure/Arrival time convenient  \
# count          103904.000000                      103904.000000
# mean                2.729683                           3.060296
# std                 1.327829                           1.525075
# min                 0.000000                           0.000000
# 25%                 2.000000                           2.000000
# 50%                 3.000000                           3.000000
# 75%                 4.000000                           4.000000
# max                 5.000000                           5.000000
#
#        Ease of Online booking  Gate location  Food and drink  Online boarding  \
# count           103904.000000  103904.000000   103904.000000    103904.000000
# mean                 2.756901       2.976883        3.202129         3.250375
# std                  1.398929       1.277621        1.329533         1.349509
# min                  0.000000       0.000000        0.000000         0.000000
# 25%                  2.000000       2.000000        2.000000         2.000000
# 50%                  3.000000       3.000000        3.000000         3.000000
# 75%                  4.000000       4.000000        4.000000         4.000000
# max                  5.000000       5.000000        5.000000         5.000000
#
#         Seat comfort  Inflight entertainment  On-board service  \
# count  103904.000000           103904.000000     103904.000000
# mean        3.439396                3.358158          3.382363
# std         1.319088                1.332991          1.288354
# min         0.000000                0.000000          0.000000
# 25%         2.000000                2.000000          2.000000
# 50%         4.000000                4.000000          4.000000
# 75%         5.000000                4.000000          4.000000
# max         5.000000                5.000000          5.000000
#
#        Leg room service  Baggage handling  Checkin service  Inflight service  \
# count     103904.000000     103904.000000    103904.000000     103904.000000
# mean           3.351055          3.631833         3.304290          3.640428
# std            1.315605          1.180903         1.265396          1.175663
# min            0.000000          1.000000         0.000000          0.000000
# 25%            2.000000          3.000000         3.000000          3.000000
# 50%            4.000000          4.000000         3.000000          4.000000
# 75%            4.000000          5.000000         4.000000          5.000000
# max            5.000000          5.000000         5.000000          5.000000
#
#          Cleanliness  Departure Delay in Minutes  Arrival Delay in Minutes
# count  103904.000000               103904.000000             103594.000000
# mean        3.286351                   14.815618                 15.178678
# std         1.312273                   38.230901                 38.698682
# min         0.000000                    0.000000                  0.000000
# 25%         2.000000                    0.000000                  0.000000
# 50%         3.000000                    0.000000                  0.000000
# 75%         4.000000                   12.000000                 13.000000
# max         5.000000                 1592.000000               1584.000000
# Unnamed: 0                             0
# id                                     0
# Gender                                 0
# Customer Type                          0
# Age                                    0
# Type of Travel                         0
# Class                                  0
# Flight Distance                        0
# Inflight wifi service                  0
# Departure/Arrival time convenient      0
# Ease of Online booking                 0
# Gate location                          0
# Food and drink                         0
# Online boarding                        0
# Seat comfort                           0
# Inflight entertainment                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# Inflight service                       0
# Cleanliness                            0
# Departure Delay in Minutes             0
# Arrival Delay in Minutes             310
# satisfaction                           0
# dtype: int64
# 18620    1
# 60015    1
# 47368    1
# 94759    1
# 23033    1
# dtype: int64

# %%
# Dataset Used : df_cat

si_cat = SimpleImputer(missing_values=np.nan, strategy='most_frequent') # Strategy = median [When Odd Number of Categories Exists]
si_cat_fit = si_cat.fit_transform(df_cat)
df_cat_mdi = pd.DataFrame(si_cat_fit, columns=df_cat.columns); df_cat_mdi # Missing Categorical Data Imputed Subset
df_cat_mdi.info()

# Impute Missing Non-Categorical Data using Descriptive Statistics : Central Tendency

# Dataset Used : df_noncat

si_noncat = SimpleImputer(missing_values=np.nan, strategy='mean') # Other Strategy : mean | median | most_frequent | constant
si_noncat_fit = si_noncat.fit_transform(df_noncat)
df_noncat_mdi_si = pd.DataFrame(si_noncat_fit, columns=df_noncat.columns); df_noncat_mdi_si # Missing Non-Categorical Data Imputed Subset using Simple Imputer
df_noncat_mdi_si.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103904 entries, 0 to 103903
# Data columns (total 19 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Gender                             103904 non-null  object
#  1   Customer Type                      103904 non-null  object
#  2   Type of Travel                     103904 non-null  object
#  3   Class                              103904 non-null  object
#  4   satisfaction                       103904 non-null  object
#  5   Inflight wifi service              103904 non-null  object
#  6   Departure/Arrival time convenient  103904 non-null  object
#  7   Ease of Online booking             103904 non-null  object
#  8   Gate location                      103904 non-null  object
#  9   Food and drink                     103904 non-null  object
#  10  Online boarding                    103904 non-null  object
#  11  Seat comfort                       103904 non-null  object
#  12  Inflight entertainment             103904 non-null  object
#  13  On-board service                   103904 non-null  object
#  14  Leg room service                   103904 non-null  object
#  15  Baggage handling                   103904 non-null  object
#  16  Checkin service                    103904 non-null  object
#  17  Inflight service                   103904 non-null  object
#  18  Cleanliness                        103904 non-null  object
# dtypes: object(19)
# memory usage: 15.1+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103904 entries, 0 to 103903
# Data columns (total 4 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Age                         103904 non-null  float64
#  1   Flight Distance             103904 non-null  float64
#  2   Departure Delay in Minutes  103904 non-null  float64
#  3   Arrival Delay in Minutes    103904 non-null  float64
# dtypes: float64(4)
# memory usage: 3.2 MB

# %%
df= df.dropna()

# %%
df=df.drop(['Unnamed: 0','id'],axis=1)

# %%
#Numeric Encoding of Categorical Data [Nominal & Ordinal]
df_cat_mdt_code = df_cat_mdi.copy()
oe = OrdinalEncoder()
oe_fit = oe.fit_transform(df_cat_mdt_code)
df_cat_code_oe = pd.DataFrame(oe_fit, columns=['Gender_code', 'Customer Type_code', 'Type of Travel_code', 'Class_code', 'satisfaction_code',
                         'Inflight wifi service_code', 'Departure/Arrival time convenient_code', 'Ease of Online booking_code',
                         'Gate location_code', 'Food and drink_code', 'Online boarding_code', 'Seat comfort_code',
                         'Inflight entertainment_code', 'On-board service_code', 'Leg room service_code',
                         'Baggage handling_code', 'Checkin service_code', 'Inflight service_code', 'Cleanliness_code']); df_cat_code_oe
df_cat_mdt_code_oe = df_cat_mdt_code.join(df_cat_code_oe); df_cat_mdt_code_oe # (Missing Data Treated) Numeric Coded Categorical Dataset using Scikit Learn Ordinal Encoder
df_cat_mdt_code_oe = pd.merge(df_cat_mdt_code, df_cat_code_oe, left_index=True, right_index=True);
df_cat_mdt_code_oe
# Out:
#         Gender      Customer Type   Type of Travel     Class  \
# 0         Male     Loyal Customer  Personal Travel  Eco Plus
# 1         Male  disloyal Customer  Business travel  Business
# 2       Female     Loyal Customer  Business travel  Business
# 3       Female     Loyal Customer  Business travel  Business
# 4         Male     Loyal Customer  Business travel  Business
# ...        ...                ...              ...       ...
# 103899  Female  disloyal Customer  Business travel       Eco
# 103900    Male     Loyal Customer  Business travel  Business
# 103901    Male  disloyal Customer  Business travel  Business
# 103902  Female  disloyal Customer  Business travel       Eco
# 103903    Male     Loyal Customer  Business travel  Business
#
#                    satisfaction Inflight wifi service  \
# 0       neutral or dissatisfied                     3
# 1       neutral or dissatisfied                     3
# 2                     satisfied                     2
# 3       neutral or dissatisfied                     2
# 4                     satisfied                     3
# ...                         ...                   ...
# 103899  neutral or dissatisfied                     2
# 103900                satisfied                     4
# 103901  neutral or dissatisfied                     1
# 103902  neutral or dissatisfied                     1
# 103903  neutral or dissatisfied                     1
#
#        Departure/Arrival time convenient Ease of Online booking Gate location  \
# 0                                      4                      3             1
# 1                                      2                      3             3
# 2                                      2                      2             2
# 3                                      5                      5             5
# 4                                      3                      3             3
# ...                                  ...                    ...           ...
# 103899                                 1                      2             3
# 103900                                 4                      4             4
# 103901                                 1                      1             3
# 103902                                 1                      1             5
# 103903                                 3                      3             3
#
#        Food and drink  ... Food and drink_code Online boarding_code  \
# 0                   5  ...                 5.0                  3.0
# 1                   1  ...                 1.0                  3.0
# 2                   5  ...                 5.0                  5.0
# 3                   2  ...                 2.0                  2.0
# 4                   4  ...                 4.0                  5.0
# ...               ...  ...                 ...                  ...
# 103899              2  ...                 2.0                  2.0
# 103900              2  ...                 2.0                  4.0
# 103901              4  ...                 4.0                  1.0
# 103902              1  ...                 1.0                  1.0
# 103903              1  ...                 1.0                  1.0
#
#        Seat comfort_code Inflight entertainment_code On-board service_code  \
# 0                    5.0                         5.0                   4.0
# 1                    1.0                         1.0                   1.0
# 2                    5.0                         5.0                   4.0
# 3                    2.0                         2.0                   2.0
# 4                    5.0                         3.0                   3.0
# ...                  ...                         ...                   ...
# 103899               2.0                         2.0                   3.0
# 103900               5.0                         5.0                   5.0
# 103901               5.0                         4.0                   3.0
# 103902               1.0                         1.0                   4.0
# 103903               1.0                         1.0                   1.0
#
#        Leg room service_code Baggage handling_code Checkin service_code  \
# 0                        3.0                   3.0                  4.0
# 1                        5.0                   2.0                  1.0
# 2                        3.0                   3.0                  4.0
# 3                        5.0                   2.0                  1.0
# 4                        4.0                   3.0                  3.0
# ...                      ...                   ...                  ...
# 103899                   1.0                   3.0                  2.0
# 103900                   5.0                   4.0                  5.0
# 103901                   2.0                   3.0                  5.0
# 103902                   5.0                   0.0                  5.0
# 103903                   1.0                   3.0                  4.0
#
#        Inflight service_code  Cleanliness_code
# 0                        5.0               5.0
# 1                        4.0               1.0
# 2                        4.0               5.0
# 3                        4.0               2.0
# 4                        3.0               3.0
# ...                      ...               ...
# 103899                   3.0               2.0
# 103900                   5.0               4.0
# 103901                   5.0               4.0
# 103902                   4.0               1.0
# 103903                   3.0               1.0
#
# [103904 rows x 38 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming df is your DataFrame and contains the columns 'Offers', 'Average Price', and 'Number of Ratings'
df_noncat_mdi_si = df[['Departure Delay in Minutes', 'Arrival Delay in Minutes']]

# Create vertical boxplot for 'Offers'
plt.figure(figsize=(8, 6))
sns.boxplot(y=df_noncat_mdi_si['Departure Delay in Minutes'])
plt.title('Boxplot of Departure Delay in Minutes')
plt.ylabel('Departure Delay in Minutes')
plt.show()

# Create vertical boxplot for 'Average Price'
plt.figure(figsize=(8, 6))
sns.boxplot(y=df_noncat_mdi_si['Arrival Delay in Minutes'])
plt.title('Boxplot of Arrival Delay in Minutes')
plt.ylabel('Arrival Delay in Minutes')
plt.show()

# %%
# 3.2.1. Normalization : Min-Max Scaling
mms = MinMaxScaler()
mms_fit = mms.fit_transform(df_noncat_mdi_si[['Departure Delay in Minutes', 'Arrival Delay in Minutes']])
df_noncat_minmax_norm = pd.DataFrame(mms_fit, columns=['Departure Delay in Minutes_mmnorm', 'Arrival Delay in Minutes_mmnorm']); df_noncat_minmax_norm

#df_noncat_minmax_norm = pd.DataFrame(mms_fit, columns=df_noncat_mdt.columns+'_mmnorm'); df_noncat_minmax_norm
df_noncat_mdt_mmn = df_noncat_mdi_si.join(df_noncat_minmax_norm);  # (Missing Data Treated) Normalized Non-Categorical Dataset using Sikit Learn Min-Max Scaler
#df_noncat_mdt_mmn = pd.merge(df_noncat_mdt, df_noncat_minmax_norm, left_index=True, right_index=True); df_noncat_mdt_mmn

df_noncat_mdt_mmn_si = SimpleImputer(missing_values=np.nan, strategy='mean') # Strategy = median [When Odd Number of Categories Exists]
df_noncat_mdt_mmn_si_fit = df_noncat_mdt_mmn_si.fit_transform(df_noncat_mdt_mmn)
df_noncat_mdt_mmn_mdi = pd.DataFrame(df_noncat_mdt_mmn_si_fit, columns=df_noncat_mdt_mmn.columns); # Missing Categorical Data Imputed Subset
df_noncat_mdt_mmn_mdi.info()

df_noncat_mdt_mmn_mdi
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103594 entries, 0 to 103593
# Data columns (total 4 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Departure Delay in Minutes         103594 non-null  float64
#  1   Arrival Delay in Minutes           103594 non-null  float64
#  2   Departure Delay in Minutes_mmnorm  103594 non-null  float64
#  3   Arrival Delay in Minutes_mmnorm    103594 non-null  float64
# dtypes: float64(4)
# memory usage: 3.2 MB
#         Departure Delay in Minutes  Arrival Delay in Minutes  \
# 0                             25.0                      18.0
# 1                              1.0                       6.0
# 2                              0.0                       0.0
# 3                             11.0                       9.0
# 4                              0.0                       0.0
# ...                            ...                       ...
# 103589                         3.0                       0.0
# 103590                         0.0                       0.0
# 103591                         7.0                      14.0
# 103592                         0.0                       0.0
# 103593                         0.0                       0.0
#
#         Departure Delay in Minutes_mmnorm  Arrival Delay in Minutes_mmnorm
# 0                                0.015704                         0.011364
# 1                                0.000628                         0.003788
# 2                                0.000000                         0.000000
# 3                                0.006910                         0.005682
# 4                                0.000000                         0.000000
# ...                                   ...                              ...
# 103589                           0.009268                         0.009587
# 103590                           0.009268                         0.009587
# 103591                           0.009268                         0.009587
# 103592                           0.009268                         0.009587
# 103593                           0.009268                         0.009587
#
# [103594 rows x 4 columns]

# %%
# Pre-Processed Dataset

# Using Scikit Learn Ordinal Encoder : df_cat_mdt_code_oe [Superior]

# Missing Data Treated & Transformed or Rescaled Non-Categorical Data Subsets

# Using Scikit Learn Standard Scaler : df_noncat_mdt_std [Standardization]


# Pre-Processed Categorical Data Subset
df_cat_ppd = df_cat_mdt_code_oe.copy(); df_cat_ppd # Preferred Data Subset

# Pre-Processed Non-Categorical Data Subset
df_noncat_ppd = df_noncat_mdt_mmn_mdi.copy(); df_noncat_ppd


# Pre-Processed Dataset
df_ppd = df_cat_ppd.join(df_noncat_ppd); df_ppd # Pre-Processed Dataset
df_ppd = pd.merge(df_cat_ppd, df_noncat_ppd, left_index=True, right_index=True); df_ppd
# Out:
#         Gender      Customer Type   Type of Travel     Class  \
# 0         Male     Loyal Customer  Personal Travel  Eco Plus
# 1         Male  disloyal Customer  Business travel  Business
# 2       Female     Loyal Customer  Business travel  Business
# 3       Female     Loyal Customer  Business travel  Business
# 4         Male     Loyal Customer  Business travel  Business
# ...        ...                ...              ...       ...
# 103589  Female     Loyal Customer  Business travel  Business
# 103590  Female     Loyal Customer  Business travel  Eco Plus
# 103591  Female     Loyal Customer  Personal Travel       Eco
# 103592    Male     Loyal Customer  Business travel  Business
# 103593    Male     Loyal Customer  Personal Travel       Eco
#
#                    satisfaction Inflight wifi service  \
# 0       neutral or dissatisfied                     3
# 1       neutral or dissatisfied                     3
# 2                     satisfied                     2
# 3       neutral or dissatisfied                     2
# 4                     satisfied                     3
# ...                         ...                   ...
# 103589  neutral or dissatisfied                     2
# 103590  neutral or dissatisfied                     3
# 103591  neutral or dissatisfied                     4
# 103592                satisfied                     4
# 103593  neutral or dissatisfied                     3
#
#        Departure/Arrival time convenient Ease of Online booking Gate location  \
# 0                                      4                      3             1
# 1                                      2                      3             3
# 2                                      2                      2             2
# 3                                      5                      5             5
# 4                                      3                      3             3
# ...                                  ...                    ...           ...
# 103589                                 5                      5             5
# 103590                                 1                      2             1
# 103591                                 5                      4             5
# 103592                                 4                      4             4
# 103593                                 5                      3             2
#
#        Food and drink  ... On-board service_code Leg room service_code  \
# 0                   5  ...                   4.0                   3.0
# 1                   1  ...                   1.0                   5.0
# 2                   5  ...                   4.0                   3.0
# 3                   2  ...                   2.0                   5.0
# 4                   4  ...                   3.0                   4.0
# ...               ...  ...                   ...                   ...
# 103589              2  ...                   1.0                   2.0
# 103590              4  ...                   3.0                   3.0
# 103591              2  ...                   4.0                   4.0
# 103592              3  ...                   4.0                   4.0
# 103593              2  ...                   4.0                   3.0
#
#        Baggage handling_code Checkin service_code Inflight service_code  \
# 0                        3.0                  4.0                   5.0
# 1                        2.0                  1.0                   4.0
# 2                        3.0                  4.0                   4.0
# 3                        2.0                  1.0                   4.0
# 4                        3.0                  3.0                   3.0
# ...                      ...                  ...                   ...
# 103589                   2.0                  4.0                   3.0
# 103590                   2.0                  4.0                   3.0
# 103591                   4.0                  5.0                   4.0
# 103592                   1.0                  3.0                   2.0
# 103593                   3.0                  5.0                   4.0
#
#        Cleanliness_code Departure Delay in Minutes Arrival Delay in Minutes  \
# 0                   5.0                       25.0                     18.0
# 1                   1.0                        1.0                      6.0
# 2                   5.0                        0.0                      0.0
# 3                   2.0                       11.0                      9.0
# 4                   3.0                        0.0                      0.0
# ...                 ...                        ...                      ...
# 103589              2.0                        3.0                      0.0
# 103590              4.0                        0.0                      0.0
# 103591              2.0                        7.0                     14.0
# 103592              3.0                        0.0                      0.0
# 103593              2.0                        0.0                      0.0
#
#        Departure Delay in Minutes_mmnorm  Arrival Delay in Minutes_mmnorm
# 0                               0.015704                         0.011364
# 1                               0.000628                         0.003788
# 2                               0.000000                         0.000000
# 3                               0.006910                         0.005682
# 4                               0.000000                         0.000000
# ...                                  ...                              ...
# 103589                          0.009268                         0.009587
# 103590                          0.009268                         0.009587
# 103591                          0.009268                         0.009587
# 103592                          0.009268                         0.009587
# 103593                          0.009268                         0.009587
#
# [103594 rows x 42 columns]

# %%
#K-Means Clustering


# 2.1.1. Determine Value of 'K' in K-Means using Elbow Curve & KMeans-Inertia

'''
KMeans-Inertia : Sum of Squared Distances of Samples to their closest Cluster Center (Centroid), Weighted by the Sample Weights (if provided)
'''
train_new_df=df_ppd[['Gender_code', 'Customer Type_code', 'Type of Travel_code', 'Class_code', 'satisfaction_code',
                         'Inflight wifi service_code', 'Departure/Arrival time convenient_code', 'Ease of Online booking_code',
                         'Gate location_code', 'Food and drink_code', 'Online boarding_code', 'Seat comfort_code',
                         'Inflight entertainment_code', 'On-board service_code', 'Leg room service_code',
                         'Baggage handling_code', 'Checkin service_code', 'Inflight service_code', 'Cleanliness_code','Departure Delay in Minutes', 'Arrival Delay in Minutes',  'Departure Delay in Minutes_mmnorm', 'Arrival Delay in Minutes_mmnorm']]
wcssd = [] # Within-Cluster-Sum-Squared-Distance
nr_clus = range(1,11) # Number of Clusters
for k in nr_clus:
    kmeans = kmclus(n_clusters=k, init='random', random_state=111)
    kmeans.fit(train_new_df)
    wcssd.append(kmeans.inertia_)
plt.plot(nr_clus, wcssd, marker='x')
plt.xlabel('Values of K')
plt.ylabel('Within Cluster Sum Squared Distance')
plt.title('Elbow Curve for Optimal K')
print(plt.show())


cluster_range = [2, 3, 4, 5]

# Iterate over different numbers of clusters
for k in cluster_range:
  # Perform Kmeans Clustering
    km_cluster = kmclus(n_clusters=k, init='random', random_state=222)
    print(km_cluster)
    km_cluster_model = km_cluster.fit_predict(train_new_df);
    print(km_cluster_model)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# None
# KMeans(init='random', n_clusters=2, random_state=222)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# [1 1 1 ... 1 1 1]
# KMeans(init='random', n_clusters=3, random_state=222)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# [2 2 2 ... 2 2 2]
# KMeans(init='random', n_clusters=4, random_state=222)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# [2 2 2 ... 2 2 2]
# KMeans(init='random', n_clusters=5, random_state=222)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# [1 2 2 ... 2 2 2]

# %%
import time
import psutil
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import seaborn as sns

# Start time
start_time = time.time()

# Specify the number of clusters
num_clusters = 4

# Initialize KMeans object
kmeans = KMeans(n_clusters=num_clusters, random_state=42)

# Fit KMeans clustering model to the data
kmeans.fit(train_new_df[['Gender_code', 'Customer Type_code', 'Type of Travel_code', 'Class_code', 'satisfaction_code',
                         'Inflight wifi service_code', 'Departure/Arrival time convenient_code', 'Ease of Online booking_code',
                         'Gate location_code', 'Food and drink_code', 'Online boarding_code', 'Seat comfort_code',
                         'Inflight entertainment_code', 'On-board service_code', 'Leg room service_code',
                         'Baggage handling_code', 'Checkin service_code', 'Inflight service_code', 'Cleanliness_code','Departure Delay in Minutes', 'Arrival Delay in Minutes',  'Departure Delay in Minutes_mmnorm', 'Arrival Delay in Minutes_mmnorm']])

# End time
end_time = time.time()

# Total time taken
time_taken = end_time - start_time
print("Time taken by K-Means for k=4:", "{:.4f} seconds".format(time_taken))

# Memory used by the KMeans model
memory_used = psutil.Process().memory_info().rss / 1024 / 1024  # Memory in MB
print("Memory used by K-Means for k=4:", "{:.2f} MB".format(memory_used))

# Get cluster labels
cluster_labels = kmeans.labels_

# Add cluster labels to DataFrame
train_new_df['cluster'] = cluster_labels

# Get centroids of each cluster
centroids = kmeans.cluster_centers_

final_df = pd.merge(df_ppd, train_new_df[['cluster']], how='left', left_index=True, right_index=True)
print(final_df)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Time taken by K-Means for k=4: 2.4661 seconds
# Memory used by K-Means for k=4: 526.79 MB
#         Gender      Customer Type   Type of Travel     Class  \
# 0         Male     Loyal Customer  Personal Travel  Eco Plus
# 1         Male  disloyal Customer  Business travel  Business
# 2       Female     Loyal Customer  Business travel  Business
# 3       Female     Loyal Customer  Business travel  Business
# 4         Male     Loyal Customer  Business travel  Business
# ...        ...                ...              ...       ...
# 103589  Female     Loyal Customer  Business travel  Business
# 103590  Female     Loyal Customer  Business travel  Eco Plus
# 103591  Female     Loyal Customer  Personal Travel       Eco
# 103592    Male     Loyal Customer  Business travel  Business
# 103593    Male     Loyal Customer  Personal Travel       Eco
#
#                    satisfaction Inflight wifi service  \
# 0       neutral or dissatisfied                     3
# 1       neutral or dissatisfied                     3
# 2                     satisfied                     2
# 3       neutral or dissatisfied                     2
# 4                     satisfied                     3
# ...                         ...                   ...
# 103589  neutral or dissatisfied                     2
# 103590  neutral or dissatisfied                     3
# 103591  neutral or dissatisfied                     4
# 103592                satisfied                     4
# 103593  neutral or dissatisfied                     3
#
#        Departure/Arrival time convenient Ease of Online booking Gate location  \
# 0                                      4                      3             1
# 1                                      2                      3             3
# 2                                      2                      2             2
# 3                                      5                      5             5
# 4                                      3                      3             3
# ...                                  ...                    ...           ...
# 103589                                 5                      5             5
# 103590                                 1                      2             1
# 103591                                 5                      4             5
# 103592                                 4                      4             4
# 103593                                 5                      3             2
#
#        Food and drink  ... Leg room service_code Baggage handling_code  \
# 0                   5  ...                   3.0                   3.0
# 1                   1  ...                   5.0                   2.0
# 2                   5  ...                   3.0                   3.0
# 3                   2  ...                   5.0                   2.0
# 4                   4  ...                   4.0                   3.0
# ...               ...  ...                   ...                   ...
# 103589              2  ...                   2.0                   2.0
# 103590              4  ...                   3.0                   2.0
# 103591              2  ...                   4.0                   4.0
# 103592              3  ...                   4.0                   1.0
# 103593              2  ...                   3.0                   3.0
#
#        Checkin service_code Inflight service_code Cleanliness_code  \
# 0                       4.0                   5.0              5.0
# 1                       1.0                   4.0              1.0
# 2                       4.0                   4.0              5.0
# 3                       1.0                   4.0              2.0
# 4                       3.0                   3.0              3.0
# ...                     ...                   ...              ...
# 103589                  4.0                   3.0              2.0
# 103590                  4.0                   3.0              4.0
# 103591                  5.0                   4.0              2.0
# 103592                  3.0                   2.0              3.0
# 103593                  5.0                   4.0              2.0
#
#        Departure Delay in Minutes Arrival Delay in Minutes  \
# 0                            25.0                     18.0
# 1                             1.0                      6.0
# 2                             0.0                      0.0
# 3                            11.0                      9.0
# 4                             0.0                      0.0
# ...                           ...                      ...
# 103589                        3.0                      0.0
# 103590                        0.0                      0.0
# 103591                        7.0                     14.0
# 103592                        0.0                      0.0
# 103593                        0.0                      0.0
#
#        Departure Delay in Minutes_mmnorm Arrival Delay in Minutes_mmnorm  \
# 0                               0.015704                        0.011364
# 1                               0.000628                        0.003788
# 2                               0.000000                        0.000000
# 3                               0.006910                        0.005682
# 4                               0.000000                        0.000000
# ...                                  ...                             ...
# 103589                          0.009268                        0.009587
# 103590                          0.009268                        0.009587
# 103591                          0.009268                        0.009587
# 103592                          0.009268                        0.009587
# 103593                          0.009268                        0.009587
#
#         cluster
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0
# ...         ...
# 103589        0
# 103590        0
# 103591        0
# 103592        0
# 103593        0
#
# [103594 rows x 43 columns]
# <ipython-input-13-5a181a8d0cee>:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_new_df['cluster'] = cluster_labels

# %%
final_new_df=final_df[['Gender_code', 'Customer Type_code', 'Type of Travel_code', 'Class_code', 'satisfaction_code',
                         'Inflight wifi service_code', 'Departure/Arrival time convenient_code', 'Ease of Online booking_code',
                         'Gate location_code', 'Food and drink_code', 'Online boarding_code', 'Seat comfort_code',
                         'Inflight entertainment_code', 'On-board service_code', 'Leg room service_code',
                         'Baggage handling_code', 'Checkin service_code', 'Inflight service_code', 'Cleanliness_code', 'cluster']]

# %%
#Subsets
df_inputs = final_df[[ 'Gender_code', 'Customer Type_code', 'Type of Travel_code', 'Class_code', 'satisfaction_code',
                         'Inflight wifi service_code', 'Departure/Arrival time convenient_code', 'Ease of Online booking_code',
                         'Gate location_code', 'Food and drink_code', 'Online boarding_code', 'Seat comfort_code',
                         'Inflight entertainment_code', 'On-board service_code', 'Leg room service_code',
                         'Baggage handling_code', 'Checkin service_code', 'Inflight service_code', 'Cleanliness_code']]; df_inputs
df_output = final_df[['cluster']]

# %%
df_inputs_names = df_inputs.columns; df_inputs_names
df_output_labels = df_output['cluster'].unique().astype(str); df_output_labels
# Out:
# array(['0', '2', '1', '3'], dtype='<U11')

# %%
# Split the df Data Subset into Training & Testing Sets
train_df_inputs, test_df_inputs, train_df_output, test_df_output = train_test_split(df_inputs, df_output, test_size=0.25, random_state=45043)

# %%
df_output.isnull().sum()
df_output.fillna(0, inplace=True)

# Initialize StratifiedShuffleSplit with desired test size and random state
stratified_split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=45043)

# Perform the stratified split to get training and testing indices
for train_index, test_index in stratified_split.split(df_inputs, df_output):
    train_df_inputs, test_df_inputs = df_inputs.iloc[train_index], df_inputs.iloc[test_index]
    train_df_output, test_df_output = df_output.iloc[train_index], df_output.iloc[test_index]
# Out:
# <ipython-input-18-6af4cbe8b63b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_output.fillna(0, inplace=True)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import SelectFromModel
import numpy as np

# Initialize Logistic Regression model with L1 regularization
logreg_l1 = LogisticRegression(penalty='l1', solver='liblinear', random_state=45043)

# Fit the model on the training data
logreg_l1.fit(train_df_inputs, train_df_output.values.ravel())

# Get feature importances from the fitted model
feature_importances = np.abs(logreg_l1.coef_).flatten()

# Calculate the threshold as 20% of the maximum feature importance
threshold = 0.2 * np.max(feature_importances)

# Create a selector object to select features based on non-zero coefficients
selector = SelectFromModel(logreg_l1, threshold=threshold)

# Transform the training and testing input data to select features
train_df_inputs_selected = selector.transform(train_df_inputs)
test_df_inputs_selected = selector.transform(test_df_inputs)

# Get the selected features
selected_features = df_inputs_names[selector.get_support()]

# Print the selected features and the calculated threshold
print("Selected Features:", selected_features)
print("Threshold:", threshold)
# Out:
# Selected Features: Index(['Gender_code', 'Customer Type_code', 'Type of Travel_code',
#        'Class_code', 'satisfaction_code', 'Inflight wifi service_code',
#        'Departure/Arrival time convenient_code', 'Ease of Online booking_code',
#        'Gate location_code', 'Food and drink_code', 'Online boarding_code',
#        'Seat comfort_code', 'Inflight entertainment_code',
#        'On-board service_code', 'Leg room service_code',
#        'Baggage handling_code', 'Checkin service_code',
#        'Inflight service_code', 'Cleanliness_code'],
#       dtype='object')
# Threshold: 0.02712884875994319
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(

# %% [markdown]
# # **Decision Tree**

# %%
# Decision Tree Clustering Model
# ------------------------------

# Decision Tree : Model (Training Subset)
dtc = DecisionTreeClassifier(criterion='gini', random_state=45043,max_depth=3) # Other Criteria : Entropy,  Log Loss
dtc_model = dtc.fit(train_df_inputs, train_df_output); dtc_model
# Out:
# DecisionTreeClassifier(max_depth=3, random_state=45043)

# %%
# Decision Tree : Model Rules
dtc_model_rules = export_text(dtc_model, feature_names = list(df_inputs_names)); print(dtc_model_rules)
# Out:
# |--- Checkin service_code <= 0.50
# |   |--- class: 2
# |--- Checkin service_code >  0.50
# |   |--- Gate location_code <= 0.50
# |   |   |--- class: 2
# |   |--- Gate location_code >  0.50
# |   |   |--- Departure/Arrival time convenient_code <= 4.50
# |   |   |   |--- class: 0
# |   |   |--- Departure/Arrival time convenient_code >  4.50
# |   |   |   |--- class: 0

# %%
# Decision Tree : Feature Importance
dtc_imp_features = pd.DataFrame({'feature': df_inputs_names, 'importance': np.round(dtc_model.feature_importances_, 3)})
dtc_imp_features.sort_values('importance', ascending=False, inplace=True); dtc_imp_features
# Out:
#                                    feature  importance
# 16                    Checkin service_code       0.355
# 8                       Gate location_code       0.355
# 6   Departure/Arrival time convenient_code       0.290
# 0                              Gender_code       0.000
# 11                       Seat comfort_code       0.000
# 17                   Inflight service_code       0.000
# 15                   Baggage handling_code       0.000
# 14                   Leg room service_code       0.000
# 13                   On-board service_code       0.000
# 12             Inflight entertainment_code       0.000
# 9                      Food and drink_code       0.000
# 10                    Online boarding_code       0.000
# 1                       Customer Type_code       0.000
# 7              Ease of Online booking_code       0.000
# 5               Inflight wifi service_code       0.000
# 4                        satisfaction_code       0.000
# 3                               Class_code       0.000
# 2                      Type of Travel_code       0.000
# 18                        Cleanliness_code       0.000

# %%
# Decision Tree : Model Prediction (Training Subset)
dtc_model_predict = dtc_model.predict(train_df_inputs); dtc_model_predict
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int32)

# %%
# Decision Tree : Prediction (Testing Subset)
dtc_predict = dtc_model.predict(test_df_inputs); dtc_predict
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int32)

# %%
# Decision Tree : Model Evaluation (Training Subset)
dtc_model_conf_mat = pd.DataFrame(confusion_matrix(train_df_output, dtc_model_predict)); dtc_model_conf_mat
dtc_model_perf = classification_report(train_df_output, dtc_model_predict); print(dtc_model_perf)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92     70502
#            1       0.00      0.00      0.00      2595
#            2       1.00      0.00      0.00      9382
#            3       0.00      0.00      0.00       396
#
#     accuracy                           0.85     82875
#    macro avg       0.46      0.25      0.23     82875
# weighted avg       0.84      0.85      0.78     82875
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Decision Tree : Prediction Evaluation (Testing Subset)
dtc_predict_conf_mat = pd.DataFrame(confusion_matrix(test_df_output, dtc_predict)); dtc_predict_conf_mat
dtc_predict_perf = classification_report(test_df_output, dtc_predict); print(dtc_predict_perf)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92     17626
#            1       0.00      0.00      0.00       648
#            2       0.00      0.00      0.00      2346
#            3       0.00      0.00      0.00        99
#
#     accuracy                           0.85     20719
#    macro avg       0.21      0.25      0.23     20719
# weighted avg       0.72      0.85      0.78     20719
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Decision Tree : Plot [Training Subset]
train_subset_dtc_plot = plot_tree(dtc_model, feature_names=df_inputs_names, class_names=df_output_labels, rounded=True, filled=True, fontsize=10)
plt.show()

# %%
# Set up the plot
ax = plt.axes()

# Plot the confusion matrix with annotations in integer format
sns.heatmap(dtc_model_conf_mat, annot=True, fmt='d', cmap='Paired')

# Set labels and title
ax.set_xlabel('Predicted Label')
ax.set_ylabel('True Label')
ax.set_title('Decision Tree : Confusion Matrix')

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, StratifiedShuffleSplit, cross_val_score
from sklearn.tree import DecisionTreeClassifier, export_text, plot_tree
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import SelectFromModel
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, f1_score
import numpy as np
import time
import psutil

# Function to measure memory usage
def memory_usage():
    process = psutil.Process()
    return process.memory_info().rss / 1024 ** 2  # Memory usage in MB

# Start time
start_time = time.time()

# Your code for data preprocessing and model training goes here...

# End time
end_time = time.time()

# Time taken
execution_time = end_time - start_time

# Memory usage
memory_used = memory_usage()

# Print memory usage and execution time
print("Memory used (MB):", memory_used)
print("Time taken (seconds):", execution_time)

# Make predictions using the trained model and measure accuracy
# Assuming you have already trained your decision tree model (dtc_model) and logistic regression model (logreg_l1)
# For example:

# Decision Tree predictions and evaluation
dtc_predict_train = dtc_model.predict(train_df_inputs)
dtc_predict_test = dtc_model.predict(test_df_inputs)

# Calculate accuracy for decision tree
accuracy_dtc_train = accuracy_score(train_df_output, dtc_predict_train)
accuracy_dtc_test = accuracy_score(test_df_output, dtc_predict_test)


# Print accuracy
print("Decision Tree Training Accuracy:", accuracy_dtc_train)
print("Decision Tree Testing Accuracy:", accuracy_dtc_test)
# Out:
# Memory used (MB): 616.81640625
# Time taken (seconds): 4.124641418457031e-05
# Decision Tree Training Accuracy: 0.8507269984917044
# Decision Tree Testing Accuracy: 0.8507167334330807

# %% [markdown]
# # **Random Forest**

# %%
## Data Visualization Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go
from wordcloud import WordCloud
from collections import Counter
from scipy import stats
from sklearn.tree import plot_tree
import graphviz
from IPython.display import display
from collections import Counter

## Machine Learning Models and Evaluation Metrics
from sklearn.ensemble import RandomForestClassifier
from sklearn.utils.validation import column_or_1d
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, f1_score, precision_recall_fscore_support
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression, Lasso, Ridge
from sklearn.metrics import make_scorer
from sklearn.pipeline import make_pipeline
from sklearn.tree import export_graphviz

# %%
rf_classifier = RandomForestClassifier(n_estimators=100, random_state=45043)

# %%
rf_classifier.fit(train_df_inputs, train_df_output['cluster'])
# Out:
# RandomForestClassifier(random_state=45043)

# %%
y_train_pred_rf = rf_classifier.predict(train_df_inputs)
y_test_pred_rf = rf_classifier.predict(test_df_inputs)

# %%
# Train the Random Forest classifier
rf_classifier.fit(train_df_inputs, train_df_output['cluster'])

# Print feature importances
feature_importances = rf_classifier.feature_importances_
feature_importance_df = pd.DataFrame({'Feature': train_df_inputs.columns, 'Importance': feature_importances})
sorted_feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)
print("Feature Importances:")
print(sorted_feature_importance_df)
# Out:
# Feature Importances:
#                                    Feature  Importance
# 16                    Checkin service_code    0.093400
# 14                   Leg room service_code    0.088370
# 13                   On-board service_code    0.071382
# 8                       Gate location_code    0.068299
# 15                   Baggage handling_code    0.066055
# 10                    Online boarding_code    0.064611
# 9                      Food and drink_code    0.064339
# 6   Departure/Arrival time convenient_code    0.063627
# 11                       Seat comfort_code    0.063124
# 17                   Inflight service_code    0.059988
# 18                        Cleanliness_code    0.056705
# 7              Ease of Online booking_code    0.053898
# 0                              Gender_code    0.042395
# 5               Inflight wifi service_code    0.041540
# 3                               Class_code    0.035989
# 12             Inflight entertainment_code    0.027505
# 4                        satisfaction_code    0.013327
# 2                      Type of Travel_code    0.012963
# 1                       Customer Type_code    0.012480

# %%
# For training set
print("Training Set Confusion Matrix:")
print(confusion_matrix(train_df_output['cluster'], y_train_pred_rf))

print("\nTraining Set Classification Report:")
print(classification_report(train_df_output['cluster'], y_train_pred_rf))
# Out:
# Training Set Confusion Matrix:
# [[65902    23   126     1]
#  [  323  2100    20     0]
#  [ 1067    20  7728     0]
#  [   44     0     3   338]]
#
# Training Set Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99     66052
#            1       0.98      0.86      0.92      2443
#            2       0.98      0.88      0.93      8815
#            3       1.00      0.88      0.93       385
#
#     accuracy                           0.98     77695
#    macro avg       0.98      0.90      0.94     77695
# weighted avg       0.98      0.98      0.98     77695

# %%
# For testing set
print("\nTesting Set Confusion Matrix:")
print(confusion_matrix(test_df_output['cluster'], y_test_pred_rf))

print("\nTesting Set Classification Report:")
print(classification_report(test_df_output['cluster'], y_test_pred_rf))
# Out:
# Testing Set Confusion Matrix:
# [[21747    64   256     9]
#  [  792     0     8     0]
#  [ 2875     4    30     4]
#  [  108     0     2     0]]
#
# Testing Set Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.99      0.91     22076
#            1       0.00      0.00      0.00       800
#            2       0.10      0.01      0.02      2913
#            3       0.00      0.00      0.00       110
#
#     accuracy                           0.84     25899
#    macro avg       0.24      0.25      0.23     25899
# weighted avg       0.74      0.84      0.78     25899

# %%
# Assuming rf is your trained Random Forest classifier
for i in range(3):
    tree = rf_classifier.estimators_[i]  # Assuming rf_classifier is your trained Random Forest model
    dot_data = export_graphviz(tree,
                               feature_names=train_df_inputs.columns,
                               filled=True,
                               max_depth=2,
                               impurity=False,
                               proportion=True)
    graph = graphviz.Source(dot_data)
    display(graph)

# %%
# Export and visualize the first three decision trees
for i in range(3):
    tree = rf_classifier.estimators_[i]
    dot_data = export_graphviz(tree,
                               feature_names=train_df_inputs.columns,
                               filled=True,
                               max_depth=2,
                               impurity=False,
                               proportion=True)
    graph = graphviz.Source(dot_data)
    display(graph)

# %%
# Initialize a dictionary to store tree frequencies and rules
tree_frequency = Counter()
tree_rules = {}

# Loop through the trees and count their frequency while storing rules
for i in range(len(rf_classifier.estimators_)):
    tree = rf_classifier.estimators_[i]
    tree_str = export_text(tree, feature_names=list(train_df_inputs.columns))
    tree_frequency[tree_str] += 1
    tree_rules[tree_str] = tree

# Get the three most frequent trees
top_trees = tree_frequency.most_common(3)

# Print the rules for the top three trees
for tree_str, frequency in top_trees:
    print(f"Tree Frequency: {frequency}")
    print(tree_str)
    print("\n")
# Out:
# Tree Frequency: 1
# |--- Ease of Online booking_code <= 0.50
# |   |--- Class_code <= 0.50
# |   |   |--- Food and drink_code <= 2.50
# |   |   |   |--- Baggage handling_code <= 1.50
# |   |   |   |   |--- Inflight wifi service_code <= 4.50
# |   |   |   |   |   |--- Cleanliness_code <= 2.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- Cleanliness_code >  2.50
# |   |   |   |   |   |   |--- Food and drink_code <= 1.50
# |   |   |   |   |   |   |   |--- Online boarding_code <= 4.50
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- Online boarding_code >  4.50
# |   |   |   |   |   |   |   |   |--- Gate location_code <= 1.50
# |   |   |   |   |   |   |   |   |   |--- class: 2.0
# |   |   |   |   |   |   |   |   |--- Gate location_code >  1.50
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- Food and drink_code >  1.50
# |   |   |   |   |   |   |   |--- Departure/Arrival time convenient_code <= 1.50
# |   |   |   |   |   |   |   |   |--- Gender_code <= 0.50
# |   |   |   |   |   |   |   |   |   |--- Baggage handling_code <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- Seat comfort_code <= 4.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |   |--- Seat comfort_code >  4.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- Baggage handling_code >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- Seat comfort_code <= 4.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |   |--- Seat comfort_code >  4.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- Gender_code >  0.50
# |   |   |   |   |   |   |   |   |   |--- Gate location_code <= 3.50
# |   |   |   |   |   |   |   |   |   |   |--- On-board service_code <= 1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |   |--- On-board service_code >  1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- Gate location_code >  3.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- Departure/Arrival time convenient_code >  1.50
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- Inflight wifi service_code >  4.50
# |   |   |   |   |   |--- class: 1.0
# |   |   |   |--- Baggage handling_code >  1.50
# |   |   |   |   |--- Cleanliness_code <= 3.50
# |   |   |   |   |   |--- Customer Type_code <= 0.50
# |   |   |   |   |   |   |--- Gender_code <= 0.50
# |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- Gender_code >  0.50
# |   |   |   |   |   |   |   |--- Inflight service_code <= 1.50
# |   |   |   |   |   |   |   |   |--- Type of Travel_code <= 0.50
# |   |   |   |   |   |   |   |   |   |--- Cleanliness_code <= 2.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2.0
# |   |   |   |   |   |   |   |   |   |--- Cleanliness_code >  2.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- Type of Travel_code >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- Inflight service_code >  1.50
# |   |   |   |   |   |   |   |   |--- Inflight service_code <= 3.50
# |   |   |   |   |   |   |   |   |   |--- Baggage handling_code <= 2.50
# |   |   |   |   |   |   |   |   |   |   |--- Online boarding_code <= 3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |   |--- Online boarding_code >  3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- Baggage handling_code >  2.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- Inflight service_code >  3.50
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- Customer Type_code >  0.50
# |   |   |   |   |   |   |--- On-board service_code <= 2.50
# |   |   |   |   |   |   |   |--- Gender_code <= 0.50
# |   |   |   |   |   |   |   |   |--- Inflight service_code <= 4.50
# |   |   |   |   |   |   |   |   |   |--- class: 3.0
# |   |   |   |   |   |   |   |   |--- Inflight service_code >  4.50
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- Gender_code >  0.50
# |   |   |   |   |   |   |   |   |--- class: 2.0
# |   |   |   |   |   |   |--- On-board service_code >  2.50
# |   |   |   |   |   |   |   |--- Cleanliness_code <= 1.50
# |   |   |   |   |   |   |   |   |--- Leg room service_code <= 3.50
# |   |   |   |   |   |   |   |   |   |--- Checkin service_code <= 2.50
# |   |   |   |   |   |   |   |   |   |   |--- Inflight service_code <= 3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2.0
# |   |   |   |   |   |   |   |   |   |   |--- Inflight service_code >  3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- Checkin service_code >  2.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- Leg room service_code >  3.50
# |   |   |   |   |   |   |   |   |   |--- satisfaction_code <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- satisfaction_code >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- Inflight service_code <= 4.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- Inflight service_code >  4.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |--- Cleanliness_code >  1.50
# |   |   |   |   |   |   |   |   |--- Gender_code <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- Gender_code >  0.50
# |   |   |   |   |   |   |   |   |   |--- Seat comfort_code <= 2.50
# |   |   |   |   |   |   |   |   |   |   |--- Baggage handling_code <= 3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |   |--- Baggage handling_code >  3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- Seat comfort_code >  2.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- Cleanliness_code >  3.50
# |   |   |   |   |   |--- Inflight entertainment_code <= 3.50
# |   |   |   |   |   |   |--- Seat comfort_code <= 2.50
# |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- Seat comfort_code >  2.50
# |   |   |   |   |   |   |   |--- Checkin service_code <= 4.50
# |   |   |   |   |   |   |   |   |--- Online boarding_code <= 3.50
# |   |   |   |   |   |   |   |   |   |--- Inflight wifi service_code <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- Inflight wifi service_code >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2.0
# |   |   |   |   |   |   |   |   |--- Online boarding_code >  3.50
# |   |   |   |   |   |   |   |   |   |--- Baggage handling_code <= 2.50
# |   |   |   |   |   |   |   |   |   |   |--- Cleanliness_code <= 4.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2.0
# |   |   |   |   |   |   |   |   |   |   |--- Cleanliness_code >  4.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- Baggage handling_code >  2.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- Checkin service_code >  4.50
# |   |   |   |   |   |   |   |   |--- Online boarding_code <= 4.50
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- Online boarding_code >  4.50
# |   |   |   |   |   |   |   |   |   |--- Cleanliness_code <= 4.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- Cleanliness_code >  4.50
# |   |   |   |   |   |   |   |   |   |   |--- Seat comfort_code <= 4.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- Seat comfort_code >  4.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- Inflight entertainment_code >  3.50
# |   |   |   |   |   |   |--- Departure/Arrival time convenient_code <= 4.50
# |   |   |   |   |   |   |   |--- Inflight service_code <= 4.50
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- Inflight service_code >  4.50
# |   |   |   |   |   |   |   |   |--- Food and drink_code <= 1.50
# |   |   |   |   |   |   |   |   |   |--- Gate location_code <= 2.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- Gate location_code >  2.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 2.0
# |   |   |   |   |   |   |   |   |--- Food and drink_code >  1.50
# |   |   |   |   |   |   |   |   |   |--- Gate location_code <= 2.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- Gate location_code >  2.50
# |   |   |   |   |   |   |   |   |   |   |--- Gate location_code <= 3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- Gate location_code >  3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- Departure/Arrival time convenient_code >  4.50
# |   |   |   |   |   |   |   |--- Gender_code <= 0.50
# |   |   |   |   |   |   |   |   |--- Online boarding_code <= 4.50
# |   |   |   |   |   |   |   |   |   |--- Checkin service_code <= 2.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- Checkin service_code >  2.50
# |   |   |   |   |   |   |   |   |   |   |--- Leg room service_code <= 2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |   |--- Leg room service_code >  2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 3.0
# |   |   |   |   |   |   |   |   |--- Online boarding_code >  4.50
# |   |   |   |   |   |   |   |   |   |--- class: 2.0
# |   |   |   |   |   |   |   |--- Gender_code >  0.50
# |   |   |   |   |   |   |   |   |--- class: 2.0
# |   |   |--- Food and drink_code >  2.50
# |   |   |   |--- Departure/Arrival time convenient_code <= 4.50
# |   |   |   |   |--- Inflight wifi service_code <= 0.50
# |   |   |   |   |   |--- Baggage handling_code <= 0.50
# |   |   |   |   |   |   |--- Inflight entertainment_code <= 2.50
# |   |   |   |   |   |   |   |--- Cleanliness_code <= 3.50
# |   |   |   |   |   |   |   |   |--- Food and drink_code <= 3.50
# |   |   |   |   |   |   |   |   |   |--- Gate location_code <= 3.50
# |   |   |   |   |   |   |   |   |   |   |--- Seat comfort_code <= 3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- Seat comfort_code >  3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- Gate location_code >  3.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- Food and drink_code >  3.50
# |   |   |   |   |   |   |   |   |   |--- Cleanliness_code <= 2.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- Cleanliness_code >  2.50
# |   |   |   |   |   |   |   |   |   |   |--- Gate location_code <= 4.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- Gate location_code >  4.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2.0
# |   |   |   |   |   |   |   |--- Cleanliness_code >  3.50
# |   |   |   |   |   |   |   |   |--- Food and drink_code <= 4.50
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- Food and drink_code >  4.50
# |   |   |   |   |   |   |   |   |   |--- Checkin service_code <= 3.50
# |   |   |   |   |   |   |   |   |   |   |--- Online boarding_code <= 4.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |   |--- Online boarding_code >  4.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2.0
# |   |   |   |   |   |   |   |   |   |--- Checkin service_code >  3.50
# |   |   |   |   |   |   |   |   |   |   |--- Checkin service_code <= 4.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- Checkin service_code >  4.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- Inflight entertainment_code >  2.50
# |   |   |   |   |   |   |   |--- Cleanliness_code <= 3.50
# |   |   |   |   |   |   |   |   |--- Seat comfort_code <= 4.50
# |   |   |   |   |   |   |   |   |   |--- Leg room service_code <= 2.50
# |   |   |   |   |   |   |   |   |   |   |--- Gate location_code <= 3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2.0
# |   |   |   |   |   |   |   |   |   |   |--- Gate location_code >  3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- Leg room service_code >  2.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- Seat comfort_code >  4.50
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- Cleanliness_code >  3.50
# |   |   |   |   |   |   |   |   |--- Inflight service_code <= 3.50
# |   |   |   |   |   |   |   |   |   |--- On-board service_code <= 2.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- On-board service_code >  2.50
# |   |   |   |   |   |   |   |   |   |   |--- Food and drink_code <= 3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2.0
# |   |   |   |   |   |   |   |   |   |   |--- Food and drink_code >  3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- Inflight service_code >  3.50
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- Baggage handling_code >  0.50
# |   |   |   |   |   |   |--- On-board service_code <= 2.50
# |   |   |   |   |   |   |   |--- Customer Type_code <= 0.50
# |   |   |   |   |   |   |   |   |--- Gender_code <= 0.50
# |   |   |   |   |   |   |   |   |   |--- Gate location_code <= 4.50
# |   |   |   |   |   |   |   |   |   |   |--- Seat comfort_code <= 4.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |   |--- Seat comfort_code >  4.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- Gate location_code >  4.50
# |   |   |   |   |   |   |   |   |   |   |--- Cleanliness_code <= 4.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- Cleanliness_code >  4.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- Gender_code >  0.50
# |   |   |   |   |   |   |   |   |   |--- Departure/Arrival time convenient_code <= 2.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- Departure/Arrival time convenient_code >  2.50
# |   |   |   |   |   |   |   |   |   |   |--- Gate location_code <= 1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- Gate location_code >  1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |--- Customer Type_code >  0.50
# |   |   |   |   |   |   |   |   |--- Seat comfort_code <= 4.00
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- Seat comfort_code >  4.00
# |   |   |   |   |   |   |   |   |   |--- class: 2.0
# |   |   |   |   |   |   |--- On-board service_code >  2.50
# |   |   |   |   |   |   |   |--- Checkin service_code <= 3.50
# |   |   |   |   |   |   |   |   |--- Gender_code <= 0.50
# |   |   |   |   |   |   |   |   |   |--- On-board service_code <= 4.50
# |   |   |   |   |   |   |   |   |   |   |--- Departure/Arrival time convenient_code <= 1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- Departure/Arrival time convenient_code >  1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- On-board service_code >  4.50
# |   |   |   |   |   |   |   |   |   |   |--- Leg room service_code <= 4.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- Leg room service_code >  4.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |--- Gender_code >  0.50
# |   |   |   |   |   |   |   |   |   |--- Food and drink_code <= 4.50
# |   |   |   |   |   |   |   |   |   |   |--- Gate location_code <= 1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- Gate location_code >  1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |--- Food and drink_code >  4.50
# |   |   |   |   |   |   |   |   |   |   |--- Inflight entertainment_code <= 4.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- Inflight entertainment_code >  4.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |--- Checkin service_code >  3.50
# |   |   |   |   |   |   |   |   |--- Cleanliness_code <= 1.50
# |   |   |   |   |   |   |   |   |   |--- Seat comfort_code <= 4.50
# |   |   |   |   |   |   |   |   |   |   |--- Inflight entertainment_code <= 3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- Inflight entertainment_code >  3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- Seat comfort_code >  4.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2.0
# |   |   |   |   |   |   |   |   |--- Cleanliness_code >  1.50
# |   |   |   |   |   |   |   |   |   |--- Checkin service_code <= 4.50
# |   |   |   |   |   |   |   |   |   |   |--- Customer Type_code <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- Customer Type_code >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |--- Checkin service_code >  4.50
# |   |   |   |   |   |   |   |   |   |   |--- Cleanliness_code <= 4.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 11
# |   |   |   |   |   |   |   |   |   |   |--- Cleanliness_code >  4.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |--- Inflight wifi service_code >  0.50
# |   |   |   |   |   |--- Seat comfort_code <= 2.50
# |   |   |   |   |   |   |--- Gate location_code <= 3.00
# |   |   |   |   |   |   |   |--- On-board service_code <= 2.00
# |   |   |   |   |   |   |   |   |--- class: 2.0
# |   |   |   |   |   |   |   |--- On-board service_code >  2.00
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- Gate location_code >  3.00
# |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- Seat comfort_code >  2.50
# |   |   |   |   |   |   |--- Inflight service_code <= 1.50
# |   |   |   |   |   |   |   |--- On-board service_code <= 2.50
# |   |   |   |   |   |   |   |   |--- Cleanliness_code <= 3.50
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- Cleanliness_code >  3.50
# |   |   |   |   |   |   |   |   |   |--- Baggage handling_code <= 1.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2.0
# |   |   |   |   |   |   |   |   |   |--- Baggage handling_code >  1.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- On-board service_code >  2.50
# |   |   |   |   |   |   |   |   |--- class: 2.0
# |   |   |   |   |   |   |--- Inflight service_code >  1.50
# |   |   |   |   |   |   |   |--- Checkin service_code <= 4.50
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- Checkin service_code >  4.50
# |   |   |   |   |   |   |   |   |--- Cleanliness_code <= 4.50
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- Cleanliness_code >  4.50
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |--- Departure/Arrival time convenient_code >  4.50
# |   |   |   |   |--- Leg room service_code <= 2.50
# |   |   |   |   |   |--- Checkin service_code <= 1.50
# |   |   |   |   |   |   |--- class: 2.0
# |   |   |   |   |   |--- Checkin service_code >  1.50
# |   |   |   |   |   |   |--- Food and drink_code <= 4.50
# |   |   |   |   |   |   |   |--- On-board service_code <= 1.50
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- On-board service_code >  1.50
# |   |   |   |   |   |   |   |   |--- satisfaction_code <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- satisfaction_code >  0.50
# |   |   |   |   |   |   |   |   |   |--- Gate location_code <= 3.50
# |   |   |   |   |   |   |   |   |   |   |--- Seat comfort_code <= 2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2.0
# |   |   |   |   |   |   |   |   |   |   |--- Seat comfort_code >  2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- Gate location_code >  3.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- Food and drink_code >  4.50
# |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- Leg room service_code >  2.50
# |   |   |   |   |   |--- Food and drink_code <= 4.50
# |   |   |   |   |   |   |--- Gender_code <= 0.50
# |   |   |   |   |   |   |   |--- Baggage handling_code <= 1.50
# |   |   |   |   |   |   |   |   |--- Inflight service_code <= 3.50
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- Inflight service_code >  3.50
# |   |   |   |   |   |   |   |   |   |--- class: 2.0
# |   |   |   |   |   |   |   |--- Baggage handling_code >  1.50
# |   |   |   |   |   |   |   |   |--- Food and drink_code <= 3.50
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- Food and drink_code >  3.50
# |   |   |   |   |   |   |   |   |   |--- Gate location_code <= 3.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- Gate location_code >  3.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2.0
# |   |   |   |   |   |   |--- Gender_code >  0.50
# |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- Food and drink_code >  4.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |--- Class_code >  0.50
# |   |   |--- Seat comfort_code <= 3.50
# |   |   |   |--- Gate location_code <= 3.50
# |   |   |   |   |--- satisfaction_code <= 0.50
# |   |   |   |   |   |--- Checkin service_code <= 4.50
# |   |   |   |   |   |   |--- On-board service_code <= 4.50
# |   |   |   |   |   |   |   |--- Departure/Arrival time convenient_code <= 1.50
# |   |   |   |   |   |   |   |   |--- Online boarding_code <= 2.50
# |   |   |   |   |   |   |   |   |   |--- Departure/Arrival time convenient_code <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- Inflight entertainment_code <= 3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- Inflight entertainment_code >  3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2.0
# |   |   |   |   |   |   |   |   |   |--- Departure/Arrival time convenient_code >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- Gate location_code <= 2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- Gate location_code >  2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- Online boarding_code >  2.50
# |   |   |   |   |   |   |   |   |   |--- Cleanliness_code <= 2.50
# |   |   |   |   |   |   |   |   |   |   |--- Checkin service_code <= 2.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- Checkin service_code >  2.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- Cleanliness_code >  2.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- Departure/Arrival time convenient_code >  1.50
# |   |   |   |   |   |   |   |   |--- Customer Type_code <= 0.50
# |   |   |   |   |   |   |   |   |   |--- On-board service_code <= 2.50
# |   |   |   |   |   |   |   |   |   |   |--- Gender_code <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- Gender_code >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- On-board service_code >  2.50
# |   |   |   |   |   |   |   |   |   |   |--- Seat comfort_code <= 2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- Seat comfort_code >  2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |--- Customer Type_code >  0.50
# |   |   |   |   |   |   |   |   |   |--- Leg room service_code <= 4.50
# |   |   |   |   |   |   |   |   |   |   |--- Baggage handling_code <= 2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |   |--- Baggage handling_code >  2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- Leg room service_code >  4.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2.0
# |   |   |   |   |   |   |--- On-board service_code >  4.50
# |   |   |   |   |   |   |   |--- Food and drink_code <= 0.50
# |   |   |   |   |   |   |   |   |--- Baggage handling_code <= 3.00
# |   |   |   |   |   |   |   |   |   |--- class: 2.0
# |   |   |   |   |   |   |   |   |--- Baggage handling_code >  3.00
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- Food and drink_code >  0.50
# |   |   |   |   |   |   |   |   |--- Class_code <= 1.50
# |   |   |   |   |   |   |   |   |   |--- Gender_code <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- Seat comfort_code <= 1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- Seat comfort_code >  1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- Gender_code >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- Seat comfort_code <= 2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- Seat comfort_code >  2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- Class_code >  1.50
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- Checkin service_code >  4.50
# |   |   |   |   |   |   |--- Inflight entertainment_code <= 1.50
# |   |   |   |   |   |   |   |--- Baggage handling_code <= 2.00
# |   |   |   |   |   |   |   |   |--- class: 2.0
# |   |   |   |   |   |   |   |--- Baggage handling_code >  2.00
# |   |   |   |   |   |   |   |   |--- Departure/Arrival time convenient_code <= 4.50
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- Departure/Arrival time convenient_code >  4.50
# |   |   |   |   |   |   |   |   |   |--- On-board service_code <= 3.50
# |   |   |   |   |   |   |   |   |   |   |--- Inflight service_code <= 3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- Inflight service_code >  3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- On-board service_code >  3.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2.0
# |   |   |   |   |   |   |--- Inflight entertainment_code >  1.50
# |   |   |   |   |   |   |   |--- Departure/Arrival time convenient_code <= 3.50
# |   |   |   |   |   |   |   |   |--- Gender_code <= 0.50
# |   |   |   |   |   |   |   |   |   |--- Inflight wifi service_code <= 2.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- Inflight wifi service_code >  2.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2.0
# |   |   |   |   |   |   |   |   |--- Gender_code >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- Departure/Arrival time convenient_code >  3.50
# |   |   |   |   |   |   |   |   |--- On-board service_code <= 3.50
# |   |   |   |   |   |   |   |   |   |--- Gate location_code <= 1.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- Gate location_code >  1.50
# |   |   |   |   |   |   |   |   |   |   |--- Baggage handling_code <= 3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- Baggage handling_code >  3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- On-board service_code >  3.50
# |   |   |   |   |   |   |   |   |   |--- Gender_code <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- Inflight wifi service_code <= 3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- Inflight wifi service_code >  3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2.0
# |   |   |   |   |   |   |   |   |   |--- Gender_code >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- Inflight service_code <= 3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- Inflight service_code >  3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- satisfaction_code >  0.50
# |   |   |   |   |   |--- Leg room service_code <= 4.50
# |   |   |   |   |   |   |--- Food and drink_code <= 0.50
# |   |   |   |   |   |   |   |--- Leg room service_code <= 3.00
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- Leg room service_code >  3.00
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- Food and drink_code >  0.50
# |   |   |   |   |   |   |   |--- Baggage handling_code <= 3.50
# |   |   |   |   |   |   |   |   |--- Gender_code <= 0.50
# |   |   |   |   |   |   |   |   |   |--- Food and drink_code <= 1.50
# |   |   |   |   |   |   |   |   |   |   |--- Inflight entertainment_code <= 2.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |   |--- Inflight entertainment_code >  2.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- Food and drink_code >  1.50
# |   |   |   |   |   |   |   |   |   |   |--- Cleanliness_code <= 3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |   |--- Cleanliness_code >  3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- Gender_code >  0.50
# |   |   |   |   |   |   |   |   |   |--- Type of Travel_code <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- Class_code <= 1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- Class_code >  1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- Type of Travel_code >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- Inflight service_code <= 3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- Inflight service_code >  3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- Baggage handling_code >  3.50
# |   |   |   |   |   |   |   |   |--- Food and drink_code <= 2.50
# |   |   |   |   |   |   |   |   |   |--- Inflight service_code <= 4.50
# |   |   |   |   |   |   |   |   |   |   |--- Inflight service_code <= 2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |   |--- Inflight service_code >  2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |--- Inflight service_code >  4.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- Food and drink_code >  2.50
# |   |   |   |   |   |   |   |   |   |--- Departure/Arrival time convenient_code <= 3.50
# |   |   |   |   |   |   |   |   |   |   |--- Inflight entertainment_code <= 3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |   |--- Inflight entertainment_code >  3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- Departure/Arrival time convenient_code >  3.50
# |   |   |   |   |   |   |   |   |   |   |--- Checkin service_code <= 1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2.0
# |   |   |   |   |   |   |   |   |   |   |--- Checkin service_code >  1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |--- Leg room service_code >  4.50
# |   |   |   |   |   |   |--- Seat comfort_code <= 1.50
# |   |   |   |   |   |   |   |--- Baggage handling_code <= 1.00
# |   |   |   |   |   |   |   |   |--- class: 2.0
# |   |   |   |   |   |   |   |--- Baggage handling_code >  1.00
# |   |   |   |   |   |   |   |   |--- Baggage handling_code <= 2.50
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- Baggage handling_code >  2.50
# |   |   |   |   |   |   |   |   |   |--- Customer Type_code <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- Gate location_code <= 2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- Gate location_code >  2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- Customer Type_code >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2.0
# |   |   |   |   |   |   |--- Seat comfort_code >  1.50
# |   |   |   |   |   |   |   |--- On-board service_code <= 1.50
# |   |   |   |   |   |   |   |   |--- Type of Travel_code <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- Type of Travel_code >  0.50
# |   |   |   |   |   |   |   |   |   |--- Inflight entertainment_code <= 4.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- Inflight entertainment_code >  4.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- On-board service_code >  1.50
# |   |   |   |   |   |   |   |   |--- Checkin service_code <= 1.50
# |   |   |   |   |   |   |   |   |   |--- Type of Travel_code <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2.0
# |   |   |   |   |   |   |   |   |   |--- Type of Travel_code >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- Checkin service_code >  1.50
# |   |   |   |   |   |   |   |   |   |--- Food and drink_code <= 4.50
# |   |   |   |   |   |   |   |   |   |   |--- Customer Type_code <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |   |--- Customer Type_code >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- Food and drink_code >  4.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2.0
# |   |   |   |--- Gate location_code >  3.50
# |   |   |   |   |--- Customer Type_code <= 0.50
# |   |   |   |   |   |--- Inflight wifi service_code <= 4.50
# |   |   |   |   |   |   |--- Class_code <= 1.50
# |   |   |   |   |   |   |   |--- Online boarding_code <= 4.50
# |   |   |   |   |   |   |   |   |--- On-board service_code <= 4.50
# |   |   |   |   |   |   |   |   |   |--- Food and drink_code <= 3.50
# |   |   |   |   |   |   |   |   |   |   |--- Type of Travel_code <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- Type of Travel_code >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 13
# |   |   |   |   |   |   |   |   |   |--- Food and drink_code >  3.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- On-board service_code >  4.50
# |   |   |   |   |   |   |   |   |   |--- Cleanliness_code <= 1.50
# |   |   |   |   |   |   |   |   |   |   |--- Departure/Arrival time convenient_code <= 4.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- Departure/Arrival time convenient_code >  4.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- Cleanliness_code >  1.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- Online boarding_code >  4.50
# |   |   |   |   |   |   |   |   |--- class: 2.0
# |   |   |   |   |   |   |--- Class_code >  1.50
# |   |   |   |   |   |   |   |--- Baggage handling_code <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- Baggage handling_code >  0.50
# |   |   |   |   |   |   |   |   |--- Food and drink_code <= 3.50
# |   |   |   |   |   |   |   |   |   |--- Baggage handling_code <= 1.50
# |   |   |   |   |   |   |   |   |   |   |--- Seat comfort_code <= 2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |   |--- Seat comfort_code >  2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- Baggage handling_code >  1.50
# |   |   |   |   |   |   |   |   |   |   |--- Inflight entertainment_code <= 1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- Inflight entertainment_code >  1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- Food and drink_code >  3.50
# |   |   |   |   |   |   |   |   |   |--- Inflight entertainment_code <= 4.50
# |   |   |   |   |   |   |   |   |   |   |--- Gender_code <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2.0
# |   |   |   |   |   |   |   |   |   |   |--- Gender_code >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- Inflight entertainment_code >  4.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2.0
# |   |   |   |   |   |--- Inflight wifi service_code >  4.50
# |   |   |   |   |   |   |--- Checkin service_code <= 3.50
# |   |   |   |   |   |   |   |--- Inflight entertainment_code <= 2.50
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- Inflight entertainment_code >  2.50
# |   |   |   |   |   |   |   |   |--- Inflight service_code <= 4.00
# |   |   |   |   |   |   |   |   |   |--- class: 2.0
# |   |   |   |   |   |   |   |   |--- Inflight service_code >  4.00
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- Checkin service_code >  3.50
# |   |   |   |   |   |   |   |--- Cleanliness_code <= 2.50
# |   |   |   |   |   |   |   |   |--- class: 2.0
# |   |   |   |   |   |   |   |--- Cleanliness_code >  2.50
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- Customer Type_code >  0.50
# |   |   |   |   |   |--- Checkin service_code <= 4.50
# |   |   |   |   |   |   |--- On-board service_code <= 4.50
# |   |   |   |   |   |   |   |--- Leg room service_code <= 3.50
# |   |   |   |   |   |   |   |   |--- Cleanliness_code <= 2.50
# |   |   |   |   |   |   |   |   |   |--- Inflight entertainment_code <= 1.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- Inflight entertainment_code >  1.50
# |   |   |   |   |   |   |   |   |   |   |--- Baggage handling_code <= 2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2.0
# |   |   |   |   |   |   |   |   |   |   |--- Baggage handling_code >  2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- Cleanliness_code >  2.50
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- Leg room service_code >  3.50
# |   |   |   |   |   |   |   |   |--- Seat comfort_code <= 1.50
# |   |   |   |   |   |   |   |   |   |--- class: 2.0
# |   |   |   |   |   |   |   |   |--- Seat comfort_code >  1.50
# |   |   |   |   |   |   |   |   |   |--- Inflight entertainment_code <= 2.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- Inflight entertainment_code >  2.50
# |   |   |   |   |   |   |   |   |   |   |--- Inflight service_code <= 1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2.0
# |   |   |   |   |   |   |   |   |   |   |--- Inflight service_code >  1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- On-board service_code >  4.50
# |   |   |   |   |   |   |   |--- Gate location_code <= 4.50
# |   |   |   |   |   |   |   |   |--- Cleanliness_code <= 3.50
# |   |   |   |   |   |   |   |   |   |--- Inflight service_code <= 3.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 2.0
# |   |   |   |   |   |   |   |   |   |--- Inflight service_code >  3.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- Cleanliness_code >  3.50
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- Gate location_code >  4.50
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- Checkin service_code >  4.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |--- Seat comfort_code >  3.50
# |   |   |   |--- Departure/Arrival time convenient_code <= 4.50
# |   |   |   |   |--- Inflight entertainment_code <= 4.50
# |   |   |   |   |   |--- Cleanliness_code <= 4.50
# |   |   |   |   |   |   |--- Gate location_code <= 4.50
# |   |   |   |   |   |   |   |--- Inflight service_code <= 2.50
# |   |   |   |   |   |   |   |   |--- Inflight service_code <= 1.50
# |   |   |   |   |   |   |   |   |   |--- Gate location_code <= 3.50
# |   |   |   |   |   |   |   |   |   |   |--- Inflight entertainment_code <= 3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- Inflight entertainment_code >  3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- Gate location_code >  3.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- Inflight service_code >  1.50
# |   |   |   |   |   |   |   |   |   |--- Baggage handling_code <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- Cleanliness_code <= 3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |   |--- Cleanliness_code >  3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- Baggage handling_code >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- Inflight service_code >  2.50
# |   |   |   |   |   |   |   |   |--- Inflight wifi service_code <= 2.50
# |   |   |   |   |   |   |   |   |   |--- Inflight service_code <= 3.50
# |   |   |   |   |   |   |   |   |   |   |--- Leg room service_code <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- Leg room service_code >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |--- Inflight service_code >  3.50
# |   |   |   |   |   |   |   |   |   |   |--- Inflight service_code <= 4.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- Inflight service_code >  4.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |--- Inflight wifi service_code >  2.50
# |   |   |   |   |   |   |   |   |   |--- Departure/Arrival time convenient_code <= 2.50
# |   |   |   |   |   |   |   |   |   |   |--- Food and drink_code <= 3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- Food and drink_code >  3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- Departure/Arrival time convenient_code >  2.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- Gate location_code >  4.50
# |   |   |   |   |   |   |   |--- Departure/Arrival time convenient_code <= 2.00
# |   |   |   |   |   |   |   |   |--- Seat comfort_code <= 4.50
# |   |   |   |   |   |   |   |   |   |--- Leg room service_code <= 2.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- Leg room service_code >  2.50
# |   |   |   |   |   |   |   |   |   |   |--- Customer Type_code <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |   |--- Customer Type_code >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- Seat comfort_code >  4.50
# |   |   |   |   |   |   |   |   |   |--- class: 2.0
# |   |   |   |   |   |   |   |--- Departure/Arrival time convenient_code >  2.00
# |   |   |   |   |   |   |   |   |--- satisfaction_code <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- satisfaction_code >  0.50
# |   |   |   |   |   |   |   |   |   |--- Inflight entertainment_code <= 3.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- Inflight entertainment_code >  3.50
# |   |   |   |   |   |   |   |   |   |   |--- Class_code <= 1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- Class_code >  1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- Cleanliness_code >  4.50
# |   |   |   |   |   |   |--- Gate location_code <= 1.50
# |   |   |   |   |   |   |   |--- Online boarding_code <= 4.50
# |   |   |   |   |   |   |   |   |--- class: 2.0
# |   |   |   |   |   |   |   |--- Online boarding_code >  4.50
# |   |   |   |   |   |   |   |   |--- Food and drink_code <= 1.00
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- Food and drink_code >  1.00
# |   |   |   |   |   |   |   |   |   |--- Checkin service_code <= 2.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- Checkin service_code >  2.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- Gate location_code >  1.50
# ...
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- Departure/Arrival time convenient_code >  3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 12
# |   |   |   |   |   |   |   |--- On-board service_code >  4.50
# |   |   |   |   |   |   |   |   |--- Online boarding_code <= 4.50
# |   |   |   |   |   |   |   |   |   |--- Ease of Online booking_code <= 3.50
# |   |   |   |   |   |   |   |   |   |   |--- Departure/Arrival time convenient_code <= 2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- Departure/Arrival time convenient_code >  2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 14
# |   |   |   |   |   |   |   |   |   |--- Ease of Online booking_code >  3.50
# |   |   |   |   |   |   |   |   |   |   |--- Baggage handling_code <= 2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |   |--- Baggage handling_code >  2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |--- Online boarding_code >  4.50
# |   |   |   |   |   |   |   |   |   |--- Type of Travel_code <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- Leg room service_code <= 2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- Leg room service_code >  2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |--- Type of Travel_code >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- Food and drink_code <= 4.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- Food and drink_code >  4.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |--- Leg room service_code >  3.50
# |   |   |   |   |--- Class_code <= 1.50
# |   |   |   |   |   |--- Food and drink_code <= 2.50
# |   |   |   |   |   |   |--- Departure/Arrival time convenient_code <= 2.50
# |   |   |   |   |   |   |   |--- Leg room service_code <= 4.50
# |   |   |   |   |   |   |   |   |--- Online boarding_code <= 4.50
# |   |   |   |   |   |   |   |   |   |--- Inflight wifi service_code <= 1.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- Inflight wifi service_code >  1.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- Online boarding_code >  4.50
# |   |   |   |   |   |   |   |   |   |--- Seat comfort_code <= 2.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2.0
# |   |   |   |   |   |   |   |   |   |--- Seat comfort_code >  2.50
# |   |   |   |   |   |   |   |   |   |   |--- Ease of Online booking_code <= 3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- Ease of Online booking_code >  3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2.0
# |   |   |   |   |   |   |   |--- Leg room service_code >  4.50
# |   |   |   |   |   |   |   |   |--- Checkin service_code <= 3.50
# |   |   |   |   |   |   |   |   |   |--- Ease of Online booking_code <= 4.00
# |   |   |   |   |   |   |   |   |   |   |--- Online boarding_code <= 4.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- Online boarding_code >  4.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- Ease of Online booking_code >  4.00
# |   |   |   |   |   |   |   |   |   |   |--- Food and drink_code <= 1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- Food and drink_code >  1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- Checkin service_code >  3.50
# |   |   |   |   |   |   |   |   |   |--- Inflight wifi service_code <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- Gender_code <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- Gender_code >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2.0
# |   |   |   |   |   |   |   |   |   |--- Inflight wifi service_code >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- Gate location_code <= 2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 11
# |   |   |   |   |   |   |   |   |   |   |--- Gate location_code >  2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |--- Departure/Arrival time convenient_code >  2.50
# |   |   |   |   |   |   |   |--- Type of Travel_code <= 0.50
# |   |   |   |   |   |   |   |   |--- Seat comfort_code <= 2.50
# |   |   |   |   |   |   |   |   |   |--- Ease of Online booking_code <= 1.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2.0
# |   |   |   |   |   |   |   |   |   |--- Ease of Online booking_code >  1.50
# |   |   |   |   |   |   |   |   |   |   |--- Ease of Online booking_code <= 4.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- Ease of Online booking_code >  4.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- Seat comfort_code >  2.50
# |   |   |   |   |   |   |   |   |   |--- Baggage handling_code <= 3.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- Baggage handling_code >  3.50
# |   |   |   |   |   |   |   |   |   |   |--- Gate location_code <= 3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 13
# |   |   |   |   |   |   |   |   |   |   |--- Gate location_code >  3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 12
# |   |   |   |   |   |   |   |--- Type of Travel_code >  0.50
# |   |   |   |   |   |   |   |   |--- Gender_code <= 0.50
# |   |   |   |   |   |   |   |   |   |--- Gate location_code <= 1.50
# |   |   |   |   |   |   |   |   |   |   |--- Inflight entertainment_code <= 3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |   |--- Inflight entertainment_code >  3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2.0
# |   |   |   |   |   |   |   |   |   |--- Gate location_code >  1.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- Gender_code >  0.50
# |   |   |   |   |   |   |   |   |   |--- Class_code <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- Class_code >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2.0
# |   |   |   |   |   |--- Food and drink_code >  2.50
# |   |   |   |   |   |   |--- Seat comfort_code <= 1.50
# |   |   |   |   |   |   |   |--- Checkin service_code <= 4.50
# |   |   |   |   |   |   |   |   |--- Food and drink_code <= 4.50
# |   |   |   |   |   |   |   |   |   |--- Gate location_code <= 1.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2.0
# |   |   |   |   |   |   |   |   |   |--- Gate location_code >  1.50
# |   |   |   |   |   |   |   |   |   |   |--- Leg room service_code <= 4.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2.0
# |   |   |   |   |   |   |   |   |   |   |--- Leg room service_code >  4.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- Food and drink_code >  4.50
# |   |   |   |   |   |   |   |   |   |--- Gate location_code <= 4.50
# |   |   |   |   |   |   |   |   |   |   |--- Class_code <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- Class_code >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |--- Gate location_code >  4.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- Checkin service_code >  4.50
# |   |   |   |   |   |   |   |   |--- Ease of Online booking_code <= 1.50
# |   |   |   |   |   |   |   |   |   |--- Food and drink_code <= 3.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- Food and drink_code >  3.50
# |   |   |   |   |   |   |   |   |   |   |--- Departure/Arrival time convenient_code <= 2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- Departure/Arrival time convenient_code >  2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- Ease of Online booking_code >  1.50
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- Seat comfort_code >  1.50
# |   |   |   |   |   |   |   |--- Online boarding_code <= 3.50
# |   |   |   |   |   |   |   |   |--- Food and drink_code <= 3.50
# |   |   |   |   |   |   |   |   |   |--- Departure/Arrival time convenient_code <= 2.50
# |   |   |   |   |   |   |   |   |   |   |--- Gender_code <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- Gender_code >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- Departure/Arrival time convenient_code >  2.50
# |   |   |   |   |   |   |   |   |   |   |--- Online boarding_code <= 2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |   |--- Online boarding_code >  2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |--- Food and drink_code >  3.50
# |   |   |   |   |   |   |   |   |   |--- Inflight wifi service_code <= 2.50
# |   |   |   |   |   |   |   |   |   |   |--- Gate location_code <= 3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 15
# |   |   |   |   |   |   |   |   |   |   |--- Gate location_code >  3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |--- Inflight wifi service_code >  2.50
# |   |   |   |   |   |   |   |   |   |   |--- Checkin service_code <= 3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- Checkin service_code >  3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 13
# |   |   |   |   |   |   |   |--- Online boarding_code >  3.50
# |   |   |   |   |   |   |   |   |--- Class_code <= 0.50
# |   |   |   |   |   |   |   |   |   |--- Checkin service_code <= 3.50
# |   |   |   |   |   |   |   |   |   |   |--- Seat comfort_code <= 3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- Seat comfort_code >  3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 16
# |   |   |   |   |   |   |   |   |   |--- Checkin service_code >  3.50
# |   |   |   |   |   |   |   |   |   |   |--- satisfaction_code <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- satisfaction_code >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 20
# |   |   |   |   |   |   |   |   |--- Class_code >  0.50
# |   |   |   |   |   |   |   |   |   |--- Customer Type_code <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- On-board service_code <= 4.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 11
# |   |   |   |   |   |   |   |   |   |   |--- On-board service_code >  4.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |--- Customer Type_code >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- Gate location_code <= 4.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |   |--- Gate location_code >  4.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |--- Class_code >  1.50
# |   |   |   |   |   |--- Baggage handling_code <= 3.50
# |   |   |   |   |   |   |--- Baggage handling_code <= 2.50
# |   |   |   |   |   |   |   |--- Checkin service_code <= 1.50
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- Checkin service_code >  1.50
# |   |   |   |   |   |   |   |   |--- Gate location_code <= 1.50
# |   |   |   |   |   |   |   |   |   |--- class: 2.0
# |   |   |   |   |   |   |   |   |--- Gate location_code >  1.50
# |   |   |   |   |   |   |   |   |   |--- Customer Type_code <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- Customer Type_code >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2.0
# |   |   |   |   |   |   |--- Baggage handling_code >  2.50
# |   |   |   |   |   |   |   |--- Ease of Online booking_code <= 4.50
# |   |   |   |   |   |   |   |   |--- Online boarding_code <= 1.50
# |   |   |   |   |   |   |   |   |   |--- class: 2.0
# |   |   |   |   |   |   |   |   |--- Online boarding_code >  1.50
# |   |   |   |   |   |   |   |   |   |--- Checkin service_code <= 3.50
# |   |   |   |   |   |   |   |   |   |   |--- Checkin service_code <= 2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |   |--- Checkin service_code >  2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- Checkin service_code >  3.50
# |   |   |   |   |   |   |   |   |   |   |--- On-board service_code <= 4.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2.0
# |   |   |   |   |   |   |   |   |   |   |--- On-board service_code >  4.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |--- Ease of Online booking_code >  4.50
# |   |   |   |   |   |   |   |   |--- Gate location_code <= 4.00
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- Gate location_code >  4.00
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- Baggage handling_code >  3.50
# |   |   |   |   |   |   |--- Inflight wifi service_code <= 4.50
# |   |   |   |   |   |   |   |--- Ease of Online booking_code <= 1.50
# |   |   |   |   |   |   |   |   |--- Seat comfort_code <= 4.00
# |   |   |   |   |   |   |   |   |   |--- class: 2.0
# |   |   |   |   |   |   |   |   |--- Seat comfort_code >  4.00
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- Ease of Online booking_code >  1.50
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- Inflight wifi service_code >  4.50
# |   |   |   |   |   |   |   |--- Gate location_code <= 4.50
# |   |   |   |   |   |   |   |   |--- Seat comfort_code <= 1.50
# |   |   |   |   |   |   |   |   |   |--- Ease of Online booking_code <= 2.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 2.0
# |   |   |   |   |   |   |   |   |   |--- Ease of Online booking_code >  2.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- Seat comfort_code >  1.50
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- Gate location_code >  4.50
# |   |   |   |   |   |   |   |   |--- Seat comfort_code <= 2.00
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- Seat comfort_code >  2.00
# |   |   |   |   |   |   |   |   |   |--- Leg room service_code <= 4.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- Leg room service_code >  4.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2.0

# %%
# Initialize a dictionary to store tree frequencies
tree_frequency = Counter()

# Loop through the trees and count their frequency
for i in range(len(rf_classifier.estimators_)):
    tree = rf_classifier.estimators_[i]
    tree_str = export_graphviz(tree, feature_names=train_df_inputs.columns,
                               filled=True, max_depth=2, impurity=False, proportion=True)
    tree_frequency[tree_str] += 1

# Get the three most frequent trees
top_trees = tree_frequency.most_common(3)

# Plot the top three trees
for tree_str, frequency in top_trees:
    graph = graphviz.Source(tree_str)
    display(graph)

# %%
import pandas as pd
import numpy as np
import time
import psutil
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# Function to measure memory usage
def memory_usage():
    process = psutil.Process()
    return process.memory_info().rss / 1024 ** 2  # Memory usage in MB

# Data preprocessing and splitting
train_df_inputs, test_df_inputs, train_df_output, test_df_output = train_test_split(df_inputs, df_output, test_size=0.25, random_state=45)

# Initialize lists to store results
models = []
training_times = []
memory_used = []
single_split_accuracies = []
cross_validation_accuracies = []

# Decision Tree
dt_start_time = time.time()
dt_model = DecisionTreeClassifier(criterion='gini', random_state=45043, max_depth=3)
dt_model.fit(train_df_inputs, train_df_output)
dt_training_time = time.time() - dt_start_time
dt_memory_used = memory_usage()
dt_pred = dt_model.predict(test_df_inputs)
dt_accuracy = accuracy_score(test_df_output, dt_pred)

# Cross-validation for Decision Tree
dtc_cv_start_time = time.time()
dtc_cv = DecisionTreeClassifier(criterion='gini', random_state=45043)
cv_scores_dtc = cross_val_score(dtc_cv, df_inputs, df_output.values.ravel(), cv=20)
dtc_cv_time = time.time() - dtc_cv_start_time
dtc_cv_accuracy = np.mean(cv_scores_dtc)

# Append Decision Tree results to lists
models.append('Decision Tree')
training_times.append(dt_training_time)
memory_used.append(dt_memory_used)
single_split_accuracies.append(dt_accuracy)
cross_validation_accuracies.append(dtc_cv_accuracy)

# Random Forest
rf_start_time = time.time()
rf_classifier = RandomForestClassifier(n_estimators=100, random_state=45043)
rf_classifier.fit(train_df_inputs, train_df_output['cluster'])
rf_training_time = time.time() - rf_start_time
rf_memory_used = memory_usage()
y_train_pred_rf = rf_classifier.predict(train_df_inputs)
y_test_pred_rf = rf_classifier.predict(test_df_inputs)
rf_accuracy_train = accuracy_score(train_df_output['cluster'], y_train_pred_rf)
rf_accuracy_test = accuracy_score(test_df_output['cluster'], y_test_pred_rf)

# Append Random Forest results to lists
models.append('Random Forest')
training_times.append(rf_training_time)
memory_used.append(rf_memory_used)
single_split_accuracies.append(rf_accuracy_test)  # Using test accuracy as we already calculated it
cross_validation_accuracies.append(np.nan)  # Cross-validation accuracy not calculated here

# Create DataFrame
results_df = pd.DataFrame({
    'Model': models,
    'Training Time (s)': training_times,
    'Memory Used (MB)': memory_used,
    'Single Split Accuracy': single_split_accuracies,
    'Cross Validation Accuracy': cross_validation_accuracies
})

# Print DataFrame
print(results_df)
# Out:
#            Model  Training Time (s)  Memory Used (MB)  Single Split Accuracy  \
# 0  Decision Tree           0.094913       1452.519531               0.852658
# 1  Random Forest          11.390221       1520.320312               0.841924
#
#    Cross Validation Accuracy
# 0                   0.723005
# 1                        NaN

# %%
# !pip install xgboost
# !pip install memory_profiler
# Out:
# Requirement already satisfied: xgboost in /usr/local/lib/python3.10/dist-packages (2.0.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from xgboost) (1.25.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from xgboost) (1.11.4)
# Requirement already satisfied: memory_profiler in /usr/local/lib/python3.10/dist-packages (0.61.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from memory_profiler) (5.9.5)

# %%
#XGboost
from xgboost.sklearn import XGBClassifier
Xgb_model = XGBClassifier()
Xgb_model.fit(train_df_inputs,train_df_output)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softprob', ...)

# %%
Xgb_pred = rf_classifier.predict(test_df_inputs)

# %%
print(classification_report(test_df_output,Xgb_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.99      0.91     22083
#            1       0.00      0.00      0.00       807
#            2       0.13      0.01      0.02      2868
#            3       0.00      0.00      0.00       141
#
#     accuracy                           0.84     25899
#    macro avg       0.24      0.25      0.23     25899
# weighted avg       0.74      0.84      0.78     25899

# %%
#XGboost
from xgboost.sklearn import XGBClassifier
import time
from memory_profiler import memory_usage

# Measure start time
start_time = time.time()

# Start memory profiler
mem_usage = memory_usage()

# Code snippet
Xgb_model = XGBClassifier()
Xgb_model.fit(train_df_inputs,train_df_output)
Xgb_pred = rf_classifier.predict(test_df_inputs)

# End memory profiler
mem_usage = memory_usage(max_usage=True)

# Measure end time
end_time = time.time()

# Calculate execution time
execution_time = end_time - start_time

print("Execution time:", execution_time, "seconds")
print("Peak memory usage:", mem_usage, "MB")
# Out:
# Execution time: 31.71205711364746 seconds
# Peak memory usage: 1557.875 MB
